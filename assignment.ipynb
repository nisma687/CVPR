# %%
import random
import os
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
folder_name_list=["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

for name in folder_name_list:
    folder_path = './train/'+name
    list_name = name
    globals()[list_name] = []

    for filename in os.listdir(folder_path):
        # Check if the file is an image
        if filename.endswith('.jpg') or filename.endswith('.png'):
            # Read the image file
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            # Add the image to the list
            if img is not None:
                globals()[list_name].append((name,img.flatten()))

# %%
bird[45]
# Out:
# ('bird', array([ 52,  66,  72, ...,  75,  98, 120], dtype=uint8))

# %%
traindata= airplane+automobile+bird+cat+deer+dog+frog+horse+ship+truck

# %%
traindata
# Out:
# [('airplane', array([197, 202, 200, ..., 238, 236, 236], dtype=uint8)),
#  ('airplane', array([108, 117, 120, ...,  89, 110, 118], dtype=uint8)),
#  ('airplane', array([249, 245, 255, ...,   8, 121, 107], dtype=uint8)),
#  ('airplane', array([255, 255, 252, ..., 252, 252, 252], dtype=uint8)),
#  ('airplane', array([47, 69, 44, ..., 42, 65, 43], dtype=uint8)),
#  ('airplane', array([158, 146, 142, ...,  65,  86,  87], dtype=uint8)),
#  ('airplane', array([231, 231, 231, ...,  95,  95,  95], dtype=uint8)),
#  ('airplane', array([ 55,  94, 109, ..., 163, 166, 171], dtype=uint8)),
#  ('airplane', array([186, 143, 100, ..., 215, 219, 224], dtype=uint8)),
#  ('airplane', array([176, 163, 171, ...,  22,  92,  86], dtype=uint8)),
#  ('airplane', array([3, 5, 0, ..., 2, 2, 0], dtype=uint8)),
#  ('airplane', array([233, 225, 218, ...,  61,  62,  58], dtype=uint8)),
#  ('airplane', array([182, 155,  91, ..., 105, 106, 102], dtype=uint8)),
#  ('airplane', array([196, 178, 167, ..., 109,  97,  91], dtype=uint8)),
#  ('airplane', array([199, 119,  94, ..., 232, 207, 191], dtype=uint8)),
#  ('airplane', array([135,  98,  84, ..., 165, 116,   0], dtype=uint8)),
#  ('airplane', array([247, 252, 250, ..., 156, 169, 177], dtype=uint8)),
#  ('airplane', array([139, 135, 124, ...,  82, 101,  98], dtype=uint8)),
#  ('airplane', array([193, 164, 150, ..., 179, 171, 171], dtype=uint8)),
#  ('airplane', array([255, 255, 198, ..., 255, 250, 243], dtype=uint8)),
#  ('airplane', array([ 96, 143, 194, ...,  57, 137, 136], dtype=uint8)),
#  ('airplane', array([235, 220, 218, ..., 189, 185, 180], dtype=uint8)),
#  ('airplane', array([143, 103,  78, ...,  83,  70,  44], dtype=uint8)),
#  ('airplane', array([169, 125,  72, ..., 152,  89,  61], dtype=uint8)),
#  ('airplane', array([236, 207, 180, ..., 213, 200, 198], dtype=uint8)),
#  ('airplane', array([101, 126, 106, ...,  98, 149, 145], dtype=uint8)),
#  ('airplane', array([209, 195, 183, ..., 193, 184, 174], dtype=uint8)),
#  ('airplane', array([252, 233, 198, ..., 241, 234, 177], dtype=uint8)),
#  ('airplane', array([178, 159, 138, ..., 184, 157, 120], dtype=uint8)),
#  ('airplane', array([151, 150, 116, ..., 160, 173, 159], dtype=uint8)),
#  ('airplane', array([224, 200, 172, ..., 120, 140, 145], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 248, 255, 252], dtype=uint8)),
#  ('airplane', array([110,  88,  70, ..., 169, 182, 190], dtype=uint8)),
#  ('airplane', array([235, 232, 224, ...,  86, 107, 105], dtype=uint8)),
#  ('airplane', array([195, 182, 160, ..., 132, 132, 132], dtype=uint8)),
#  ('airplane', array([243, 243, 243, ...,  33,  33,  33], dtype=uint8)),
#  ('airplane', array([217, 193, 171, ..., 159, 149, 142], dtype=uint8)),
#  ('airplane', array([112,  65,  51, ...,  74,  82, 105], dtype=uint8)),
#  ('airplane', array([228, 199, 168, ...,  66, 114, 118], dtype=uint8)),
#  ('airplane', array([246, 252, 255, ..., 252, 253, 251], dtype=uint8)),
#  ('airplane', array([110,  44,   9, ...,  92, 114, 139], dtype=uint8)),
#  ('airplane', array([231, 231, 231, ..., 103, 103, 103], dtype=uint8)),
#  ('airplane', array([196, 184, 156, ..., 195, 179, 166], dtype=uint8)),
#  ('airplane', array([251, 240, 250, ..., 100, 102,  60], dtype=uint8)),
#  ('airplane', array([212, 170, 141, ...,  68, 109, 124], dtype=uint8)),
#  ('airplane', array([234, 226, 233, ..., 240, 227, 229], dtype=uint8)),
#  ('airplane', array([160, 103, 128, ..., 126,  75,  79], dtype=uint8)),
#  ('airplane', array([151, 149, 149, ...,  83,  78,  79], dtype=uint8)),
#  ('airplane', array([197, 127,  74, ..., 198, 138,  78], dtype=uint8)),
#  ('airplane', array([179, 179, 185, ..., 178, 189, 203], dtype=uint8)),
#  ('airplane', array([184, 164, 163, ..., 159, 143, 144], dtype=uint8)),
#  ('airplane', array([223, 215, 222, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([203, 194, 151, ...,  61,  73,  83], dtype=uint8)),
#  ('airplane', array([250, 239, 242, ...,  88,  75,  61], dtype=uint8)),
#  ('airplane', array([181, 173, 166, ..., 159, 143, 131], dtype=uint8)),
#  ('airplane', array([115,  84,  75, ..., 108,  97,  93], dtype=uint8)),
#  ('airplane', array([224, 211, 209, ..., 214, 204, 204], dtype=uint8)),
#  ('airplane', array([241, 207, 183, ...,  92, 121,  95], dtype=uint8)),
#  ('airplane', array([125, 125,  41, ..., 119, 129,  29], dtype=uint8)),
#  ('airplane', array([ 63,  63,  63, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([200, 203, 194, ...,  64,  74,  74], dtype=uint8)),
#  ('airplane', array([ 82,  75,  80, ..., 116, 116, 132], dtype=uint8)),
#  ('airplane', array([ 88, 101, 133, ...,  49,  60,  74], dtype=uint8)),
#  ('airplane', array([202, 223, 225, ..., 163, 180, 193], dtype=uint8)),
#  ('airplane', array([186, 136,   0, ..., 238, 235, 231], dtype=uint8)),
#  ('airplane', array([253, 255, 251, ..., 248, 255, 255], dtype=uint8)),
#  ('airplane', array([112, 106, 107, ..., 146, 138, 131], dtype=uint8)),
#  ('airplane', array([233, 180, 129, ..., 242, 170, 128], dtype=uint8)),
#  ('airplane', array([213, 186, 142, ..., 237, 208, 163], dtype=uint8)),
#  ('airplane', array([254, 253, 249, ..., 254, 250, 249], dtype=uint8)),
#  ('airplane', array([190, 194, 182, ..., 180, 183, 187], dtype=uint8)),
#  ('airplane', array([202, 188, 169, ..., 187, 184, 170], dtype=uint8)),
#  ('airplane', array([184, 169, 160, ..., 118, 109, 122], dtype=uint8)),
#  ('airplane', array([231, 228, 213, ..., 149, 160, 144], dtype=uint8)),
#  ('airplane', array([159, 173, 185, ..., 208, 219, 239], dtype=uint8)),
#  ('airplane', array([232, 232, 232, ..., 250, 250, 250], dtype=uint8)),
#  ('airplane', array([156, 110,  52, ..., 151, 116,  50], dtype=uint8)),
#  ('airplane', array([249, 254, 255, ...,   0,   0,   0], dtype=uint8)),
#  ('airplane', array([239, 209, 122, ..., 119, 130, 120], dtype=uint8)),
#  ('airplane', array([198, 116,  38, ..., 115, 135, 140], dtype=uint8)),
#  ('airplane', array([188, 139,  65, ..., 231, 187, 134], dtype=uint8)),
#  ('airplane', array([146, 118, 101, ..., 219, 207, 205], dtype=uint8)),
#  ('airplane', array([239, 239, 239, ..., 225, 225, 225], dtype=uint8)),
#  ('airplane', array([ 34, 105,  88, ...,  19,  70,  63], dtype=uint8)),
#  ('airplane', array([ 57, 101,  88, ...,  48,  88,  76], dtype=uint8)),
#  ('airplane', array([133, 137, 126, ..., 113, 113, 113], dtype=uint8)),
#  ('airplane', array([213, 201, 191, ..., 211, 187, 181], dtype=uint8)),
#  ('airplane', array([254, 230, 224, ...,  74, 101,  91], dtype=uint8)),
#  ('airplane', array([238, 215, 199, ...,  86,  85,  94], dtype=uint8)),
#  ('airplane', array([219, 206, 190, ..., 167, 153, 141], dtype=uint8)),
#  ('airplane', array([213, 183, 182, ..., 128, 168, 173], dtype=uint8)),
#  ('airplane', array([246, 243, 238, ..., 121,  75,  41], dtype=uint8)),
#  ('airplane', array([226, 184, 137, ...,  93, 102, 111], dtype=uint8)),
#  ('airplane', array([115,  89,  73, ...,  74,  77,  81], dtype=uint8)),
#  ('airplane', array([231, 202, 193, ..., 113, 131, 124], dtype=uint8)),
#  ('airplane', array([178, 140, 110, ..., 108, 101,  76], dtype=uint8)),
#  ('airplane', array([160, 158,  26, ..., 220, 221, 181], dtype=uint8)),
#  ('airplane', array([174, 155, 164, ...,  36,  41,  62], dtype=uint8)),
#  ('airplane', array([255, 253, 255, ..., 196, 185, 205], dtype=uint8)),
#  ('airplane', array([142, 140, 109, ..., 139, 137, 119], dtype=uint8)),
#  ('airplane', array([176, 144,  73, ...,  44,  98,  61], dtype=uint8)),
#  ('airplane', array([192, 203, 225, ..., 169, 185, 197], dtype=uint8)),
#  ('airplane', array([147, 151, 122, ...,  67,  62,  59], dtype=uint8)),
#  ('airplane', array([121,  89,  76, ...,  51,  42,  45], dtype=uint8)),
#  ('airplane', array([254, 196,  83, ..., 113,  92,  71], dtype=uint8)),
#  ('airplane', array([192, 123, 103, ..., 115, 131, 154], dtype=uint8)),
#  ('airplane', array([237, 240, 244, ...,  13,  87,  83], dtype=uint8)),
#  ('airplane', array([195, 189, 176, ...,  53,  52,  61], dtype=uint8)),
#  ('airplane', array([153, 167, 165, ...,  30,  61,  40], dtype=uint8)),
#  ('airplane', array([191, 204, 218, ...,  19,  38,  29], dtype=uint8)),
#  ('airplane', array([247, 236, 214, ..., 194, 177, 198], dtype=uint8)),
#  ('airplane', array([239, 226, 194, ..., 185, 232, 236], dtype=uint8)),
#  ('airplane', array([248, 255, 255, ..., 253, 255, 255], dtype=uint8)),
#  ('airplane', array([142,  93,  79, ..., 127, 127, 113], dtype=uint8)),
#  ('airplane', array([246, 238, 225, ..., 221, 204, 178], dtype=uint8)),
#  ('airplane', array([229, 184, 147, ..., 227, 189, 155], dtype=uint8)),
#  ('airplane', array([233, 234, 224, ..., 110, 132, 143], dtype=uint8)),
#  ('airplane', array([187, 160, 169, ...,  69,  21,  27], dtype=uint8)),
#  ('airplane', array([149, 178, 215, ...,  87, 123, 171], dtype=uint8)),
#  ('airplane', array([252, 231, 240, ..., 118, 117, 127], dtype=uint8)),
#  ('airplane', array([197, 104,  41, ..., 123,  67,  38], dtype=uint8)),
#  ('airplane', array([254, 254, 254, ..., 242, 255, 251], dtype=uint8)),
#  ('airplane', array([242, 240, 232, ..., 187, 194, 197], dtype=uint8)),
#  ('airplane', array([191, 196, 187, ...,   8,  64,  81], dtype=uint8)),
#  ('airplane', array([144, 151, 170, ...,  79, 113, 142], dtype=uint8)),
#  ('airplane', array([177, 174, 169, ...,  19,  49,  36], dtype=uint8)),
#  ('airplane', array([184, 124,  82, ..., 196, 131,  76], dtype=uint8)),
#  ('airplane', array([213, 171, 142, ..., 213, 182, 159], dtype=uint8)),
#  ('airplane', array([221, 217, 192, ..., 220, 242, 237], dtype=uint8)),
#  ('airplane', array([22,  5,  2, ..., 96, 65, 44], dtype=uint8)),
#  ('airplane', array([239, 221, 214, ..., 255, 252, 240], dtype=uint8)),
#  ('airplane', array([236, 211, 195, ...,  94, 163, 130], dtype=uint8)),
#  ('airplane', array([152, 125,  74, ..., 175, 186, 170], dtype=uint8)),
#  ('airplane', array([167, 155, 137, ..., 112, 123,  97], dtype=uint8)),
#  ('airplane', array([162,  92,  62, ..., 177, 106,  69], dtype=uint8)),
#  ('airplane', array([221, 218, 197, ...,  94, 135, 127], dtype=uint8)),
#  ('airplane', array([243, 218, 216, ..., 185, 112,  74], dtype=uint8)),
#  ('airplane', array([252, 244, 255, ..., 247, 245, 255], dtype=uint8)),
#  ('airplane', array([161, 151, 144, ..., 133, 138, 137], dtype=uint8)),
#  ('airplane', array([204, 150, 127, ..., 244, 248, 243], dtype=uint8)),
#  ('airplane', array([250, 255, 255, ..., 255, 255, 252], dtype=uint8)),
#  ('airplane', array([103, 101,  60, ..., 116, 121,  94], dtype=uint8)),
#  ('airplane', array([125,  45,  16, ..., 142,  79,   0], dtype=uint8)),
#  ('airplane', array([227, 198, 191, ..., 150, 101,   0], dtype=uint8)),
#  ('airplane', array([212, 204, 174, ..., 243, 234, 207], dtype=uint8)),
#  ('airplane', array([180, 206, 190, ..., 160, 191, 192], dtype=uint8)),
#  ('airplane', array([253, 242, 210, ..., 200, 223, 239], dtype=uint8)),
#  ('airplane', array([122, 145, 207, ..., 157, 151, 174], dtype=uint8)),
#  ('airplane', array([222, 199, 137, ..., 109, 118, 115], dtype=uint8)),
#  ('airplane', array([169, 154, 151, ..., 129, 107,  79], dtype=uint8)),
#  ('airplane', array([71, 54, 75, ..., 10,  9, 13], dtype=uint8)),
#  ('airplane', array([124, 174, 204, ..., 123, 150, 170], dtype=uint8)),
#  ('airplane', array([199, 204, 203, ...,  93,  81,  75], dtype=uint8)),
#  ('airplane', array([249, 248, 250, ..., 114, 149, 199], dtype=uint8)),
#  ('airplane', array([220, 171, 131, ..., 233, 194, 162], dtype=uint8)),
#  ('airplane', array([221, 162, 100, ..., 247, 247, 247], dtype=uint8)),
#  ('airplane', array([141, 124, 127, ..., 183, 167, 160], dtype=uint8)),
#  ('airplane', array([238, 229, 215, ..., 228, 222, 209], dtype=uint8)),
#  ('airplane', array([179, 148, 115, ..., 195, 149, 115], dtype=uint8)),
#  ('airplane', array([111, 129,  76, ..., 124, 138, 114], dtype=uint8)),
#  ('airplane', array([ 61,  60,  64, ..., 142, 156, 174], dtype=uint8)),
#  ('airplane', array([203, 190, 188, ..., 205, 184, 176], dtype=uint8)),
#  ('airplane', array([194, 176, 183, ..., 192, 183, 180], dtype=uint8)),
#  ('airplane', array([218, 211, 194, ..., 194, 159, 145], dtype=uint8)),
#  ('airplane', array([203, 173, 124, ..., 128, 124, 129], dtype=uint8)),
#  ('airplane', array([166,  90,  38, ..., 252, 213, 191], dtype=uint8)),
#  ('airplane', array([211, 186, 166, ..., 228, 218, 211], dtype=uint8)),
#  ('airplane', array([222, 176, 145, ..., 168, 177, 181], dtype=uint8)),
#  ('airplane', array([142,  92,  74, ..., 245, 230, 238], dtype=uint8)),
#  ('airplane', array([231, 154,  98, ..., 107, 107, 107], dtype=uint8)),
#  ('airplane', array([174, 162, 156, ..., 209, 206, 202], dtype=uint8)),
#  ('airplane', array([205, 144,  78, ..., 243, 233, 226], dtype=uint8)),
#  ('airplane', array([215, 215, 233, ..., 220, 219, 235], dtype=uint8)),
#  ('airplane', array([103, 103, 103, ...,  89,  89,  89], dtype=uint8)),
#  ('airplane', array([179, 122,  23, ..., 222, 216, 193], dtype=uint8)),
#  ('airplane', array([242, 242, 242, ..., 140, 140, 140], dtype=uint8)),
#  ('airplane', array([221, 213, 224, ..., 148, 152, 157], dtype=uint8)),
#  ('airplane', array([249, 244, 243, ...,  72,  43,  28], dtype=uint8)),
#  ('airplane', array([123,  80,   1, ..., 235, 208, 188], dtype=uint8)),
#  ('airplane', array([186, 131, 104, ..., 162, 151, 131], dtype=uint8)),
#  ('airplane', array([162, 158, 109, ...,  35,  43,  42], dtype=uint8)),
#  ('airplane', array([215, 215, 215, ..., 213, 213, 213], dtype=uint8)),
#  ('airplane', array([190, 177, 169, ..., 119, 121, 121], dtype=uint8)),
#  ('airplane', array([193, 184, 170, ..., 114, 139, 179], dtype=uint8)),
#  ('airplane', array([165, 149, 143, ..., 160, 148, 144], dtype=uint8)),
#  ('airplane', array([187, 177, 189, ..., 145, 162, 195], dtype=uint8)),
#  ('airplane', array([174, 179, 178, ..., 140, 128, 122], dtype=uint8)),
#  ('airplane', array([152, 129, 107, ...,  74,  88, 100], dtype=uint8)),
#  ('airplane', array([227, 147, 130, ..., 202, 109,  88], dtype=uint8)),
#  ('airplane', array([209, 210, 214, ..., 123, 144, 152], dtype=uint8)),
#  ('airplane', array([21, 21, 21, ..., 24, 24, 24], dtype=uint8)),
#  ('airplane', array([164, 132, 126, ..., 168, 153, 127], dtype=uint8)),
#  ('airplane', array([ 95,  73,  68, ..., 121, 145, 151], dtype=uint8)),
#  ('airplane', array([177, 150, 154, ...,  97,  87, 104], dtype=uint8)),
#  ('airplane', array([ 89,  68,  71, ..., 133,  98, 112], dtype=uint8)),
#  ('airplane', array([71, 84,  0, ..., 66, 54, 18], dtype=uint8)),
#  ('airplane', array([252, 252, 252, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([136, 111,  79, ...,  93, 128, 132], dtype=uint8)),
#  ('airplane', array([0, 0, 1, ..., 0, 2, 0], dtype=uint8)),
#  ('airplane', array([173, 128,  84, ...,  16,  25,  35], dtype=uint8)),
#  ('airplane', array([30, 63, 56, ..., 45, 79, 69], dtype=uint8)),
#  ('airplane', array([214, 196, 135, ..., 102, 148, 135], dtype=uint8)),
#  ('airplane', array([127, 155, 239, ...,  76, 125, 199], dtype=uint8)),
#  ('airplane', array([ 95, 125, 172, ...,  24,  13,  33], dtype=uint8)),
#  ('airplane', array([243, 177, 124, ..., 227, 205, 177], dtype=uint8)),
#  ('airplane', array([249, 249, 249, ..., 246, 246, 246], dtype=uint8)),
#  ('airplane', array([221, 215, 208, ...,  27,  63,  69], dtype=uint8)),
#  ('airplane', array([188, 172, 160, ..., 186, 169, 156], dtype=uint8)),
#  ('airplane', array([137, 118, 103, ..., 132, 144, 146], dtype=uint8)),
#  ('airplane', array([ 14,  60, 172, ...,   0,   4,  21], dtype=uint8)),
#  ('airplane', array([205, 205, 189, ..., 194, 192, 181], dtype=uint8)),
#  ('airplane', array([175, 165, 165, ..., 137, 131, 136], dtype=uint8)),
#  ('airplane', array([155,  95,  19, ..., 161, 140,  95], dtype=uint8)),
#  ('airplane', array([225, 174, 134, ..., 228, 177, 145], dtype=uint8)),
#  ('airplane', array([225, 195, 178, ..., 111,  99, 135], dtype=uint8)),
#  ('airplane', array([169, 172, 170, ...,  10,  10,   4], dtype=uint8)),
#  ('airplane', array([168, 156, 108, ..., 173, 187, 183], dtype=uint8)),
#  ('airplane', array([192, 157, 123, ...,  12,   7,   4], dtype=uint8)),
#  ('airplane', array([138,  91,  53, ...,  56,  30,  18], dtype=uint8)),
#  ('airplane', array([176, 148, 114, ...,  24,  57,  73], dtype=uint8)),
#  ('airplane', array([214, 209, 210, ...,  73, 105, 111], dtype=uint8)),
#  ('airplane', array([48, 27, 25, ..., 41, 29, 19], dtype=uint8)),
#  ('airplane', array([60, 80, 81, ..., 22, 51, 42], dtype=uint8)),
#  ('airplane', array([ 35,  37,  77, ...,  93, 120, 171], dtype=uint8)),
#  ('airplane', array([193, 185, 192, ..., 132,  87,  30], dtype=uint8)),
#  ('airplane', array([113,  52,  20, ..., 105,  56,  16], dtype=uint8)),
#  ('airplane', array([ 79, 147, 192, ..., 179, 182, 196], dtype=uint8)),
#  ('airplane', array([104, 107, 122, ..., 106, 128, 169], dtype=uint8)),
#  ('airplane', array([157,  94,  56, ...,  77,  70,  55], dtype=uint8)),
#  ('airplane', array([224, 199, 165, ..., 184, 190, 179], dtype=uint8)),
#  ('airplane', array([63, 56, 59, ..., 61, 50, 58], dtype=uint8)),
#  ('airplane', array([125,  85,  66, ...,  34,  73,  48], dtype=uint8)),
#  ('airplane', array([124, 113,  81, ...,  70,  69,  55], dtype=uint8)),
#  ('airplane', array([161, 137, 137, ...,  40,  39,  35], dtype=uint8)),
#  ('airplane', array([232, 203, 189, ..., 131, 154, 192], dtype=uint8)),
#  ('airplane', array([237, 222, 219, ..., 158, 129, 120], dtype=uint8)),
#  ('airplane', array([189, 134,   0, ..., 230, 231, 227], dtype=uint8)),
#  ('airplane', array([183, 185, 195, ..., 171, 163, 174], dtype=uint8)),
#  ('airplane', array([ 75,  96,  97, ..., 121, 121, 135], dtype=uint8)),
#  ('airplane', array([236, 219, 228, ..., 159, 112,  91], dtype=uint8)),
#  ('airplane', array([248, 223, 179, ..., 193, 153, 111], dtype=uint8)),
#  ('airplane', array([182, 185, 153, ..., 232, 240, 240], dtype=uint8)),
#  ('airplane', array([152, 145, 126, ..., 166, 137, 130], dtype=uint8)),
#  ('airplane', array([178, 142, 124, ..., 167, 170, 178], dtype=uint8)),
#  ('airplane', array([207, 198, 148, ..., 237, 219, 178], dtype=uint8)),
#  ('airplane', array([245, 245, 245, ..., 224, 227, 231], dtype=uint8)),
#  ('airplane', array([104, 134, 135, ..., 204, 230, 244], dtype=uint8)),
#  ('airplane', array([202, 206, 207, ..., 175, 183, 182], dtype=uint8)),
#  ('airplane', array([166, 147, 134, ..., 166, 152, 140], dtype=uint8)),
#  ('airplane', array([244, 194, 164, ..., 248, 207, 168], dtype=uint8)),
#  ('airplane', array([177, 138, 129, ...,  47,  77,  78], dtype=uint8)),
#  ('airplane', array([225, 223, 222, ..., 160, 156, 145], dtype=uint8)),
#  ('airplane', array([156, 153, 138, ...,  19,  19,   1], dtype=uint8)),
#  ('airplane', array([178, 186, 156, ..., 152, 142,  48], dtype=uint8)),
#  ('airplane', array([211, 150, 100, ..., 116, 111,  90], dtype=uint8)),
#  ('airplane', array([174, 170, 146, ..., 171, 200, 207], dtype=uint8)),
#  ('airplane', array([161, 112,  80, ...,  31,  41,  35], dtype=uint8)),
#  ('airplane', array([255, 253, 255, ..., 239, 255, 255], dtype=uint8)),
#  ('airplane', array([184, 186, 187, ..., 189, 194, 192], dtype=uint8)),
#  ('airplane', array([245, 202, 175, ...,  18,  14,  13], dtype=uint8)),
#  ('airplane', array([149, 166, 169, ..., 209, 208, 217], dtype=uint8)),
#  ('airplane', array([133, 178, 222, ..., 181, 202, 204], dtype=uint8)),
#  ('airplane', array([218, 232, 226, ..., 198, 187, 179], dtype=uint8)),
#  ('airplane', array([194, 176, 153, ..., 192, 174, 157], dtype=uint8)),
#  ('airplane', array([225, 210, 208, ...,  67,  86,  93], dtype=uint8)),
#  ('airplane', array([255, 244, 221, ...,  89, 105, 112], dtype=uint8)),
#  ('airplane', array([144, 101,  82, ...,   5,   9,  33], dtype=uint8)),
#  ('airplane', array([118,  58,  22, ..., 130,  77,  26], dtype=uint8)),
#  ('airplane', array([247, 238, 229, ..., 242, 239, 231], dtype=uint8)),
#  ('airplane', array([202, 142,  88, ...,  22,  29,  44], dtype=uint8)),
#  ('airplane', array([111, 164, 245, ...,  32,  33,  43], dtype=uint8)),
#  ('airplane', array([132, 132, 118, ...,  53,  86,  72], dtype=uint8)),
#  ('airplane', array([ 87,  36,  16, ..., 171, 180, 160], dtype=uint8)),
#  ('airplane', array([218, 210, 211, ...,  75,  95,  90], dtype=uint8)),
#  ('airplane', array([148,  91,  36, ...,  59,  64,  73], dtype=uint8)),
#  ('airplane', array([245, 252, 247, ..., 212, 211, 220], dtype=uint8)),
#  ('airplane', array([250, 238, 198, ..., 148, 209, 241], dtype=uint8)),
#  ('airplane', array([181, 155, 143, ...,  46,  68, 110], dtype=uint8)),
#  ('airplane', array([208, 156, 103, ..., 255, 220, 156], dtype=uint8)),
#  ('airplane', array([192, 121,  71, ..., 255, 254, 242], dtype=uint8)),
#  ('airplane', array([241, 185, 144, ..., 240, 178, 137], dtype=uint8)),
#  ('airplane', array([179, 179, 179, ..., 174, 139,  99], dtype=uint8)),
#  ('airplane', array([121, 116, 117, ...,  85,  88, 103], dtype=uint8)),
#  ('airplane', array([210, 210, 216, ..., 157, 141, 148], dtype=uint8)),
#  ('airplane', array([125, 127, 135, ..., 103, 101, 101], dtype=uint8)),
#  ('airplane', array([206, 227, 249, ...,  51,  35,  36], dtype=uint8)),
#  ('airplane', array([141, 147, 142, ...,  80,  70, 224], dtype=uint8)),
#  ('airplane', array([255, 254, 204, ..., 171, 162, 148], dtype=uint8)),
#  ('airplane', array([237, 211, 205, ..., 235, 246, 255], dtype=uint8)),
#  ('airplane', array([141,  92,  82, ..., 182, 135, 107], dtype=uint8)),
#  ('airplane', array([170, 152, 153, ...,  57,  94, 108], dtype=uint8)),
#  ('airplane', array([ 8,  9,  5, ..., 56, 85, 89], dtype=uint8)),
#  ('airplane', array([145, 149, 150, ..., 141, 163, 181], dtype=uint8)),
#  ('airplane', array([255, 251, 255, ..., 164, 158, 147], dtype=uint8)),
#  ('airplane', array([46, 50, 45, ..., 57, 55, 47], dtype=uint8)),
#  ('airplane', array([168, 159, 155, ...,  90,  93, 107], dtype=uint8)),
#  ('airplane', array([170, 105,  67, ..., 204, 114,  67], dtype=uint8)),
#  ('airplane', array([146, 111, 115, ..., 142, 121, 119], dtype=uint8)),
#  ('airplane', array([152, 140, 160, ..., 144, 129, 133], dtype=uint8)),
#  ('airplane', array([218, 182, 174, ..., 146, 143, 138], dtype=uint8)),
#  ('airplane', array([251, 255, 255, ..., 185, 202, 189], dtype=uint8)),
#  ('airplane', array([160, 135, 101, ...,  88,  67,  35], dtype=uint8)),
#  ('airplane', array([178, 127,  84, ..., 159, 141,  88], dtype=uint8)),
#  ('airplane', array([161, 114, 100, ..., 135, 101,  85], dtype=uint8)),
#  ('airplane', array([210, 166,  82, ..., 235, 226, 236], dtype=uint8)),
#  ('airplane', array([202, 181, 173, ...,  23,  54,  51], dtype=uint8)),
#  ('airplane', array([188, 163, 147, ..., 184, 165, 152], dtype=uint8)),
#  ('airplane', array([212, 163, 101, ...,  64,  86,  98], dtype=uint8)),
#  ('airplane', array([141, 145, 140, ..., 165, 174, 171], dtype=uint8)),
#  ('airplane', array([242, 246, 255, ..., 254, 235, 230], dtype=uint8)),
#  ('airplane', array([155, 123, 117, ..., 128, 131, 139], dtype=uint8)),
#  ('airplane', array([109,  57,  27, ..., 104,  59,  46], dtype=uint8)),
#  ('airplane', array([167, 128,  90, ...,  84,  94, 104], dtype=uint8)),
#  ('airplane', array([225, 226, 236, ..., 230, 229, 231], dtype=uint8)),
#  ('airplane', array([36, 36, 36, ..., 66, 66, 66], dtype=uint8)),
#  ('airplane', array([253, 206, 184, ..., 189, 164, 160], dtype=uint8)),
#  ('airplane', array([215, 198, 171, ..., 222, 220, 220], dtype=uint8)),
#  ('airplane', array([226, 213, 197, ..., 246, 234, 230], dtype=uint8)),
#  ('airplane', array([78, 72, 65, ..., 70, 81, 79], dtype=uint8)),
#  ('airplane', array([ 5,  1,  7, ..., 16,  8, 19], dtype=uint8)),
#  ('airplane', array([242, 223, 210, ...,  77, 121, 120], dtype=uint8)),
#  ('airplane', array([140, 109, 100, ..., 177, 186, 196], dtype=uint8)),
#  ('airplane', array([219, 229, 239, ..., 123, 110, 102], dtype=uint8)),
#  ('airplane', array([218, 209, 206, ...,  92,  81,  67], dtype=uint8)),
#  ('airplane', array([220, 241, 243, ..., 113, 135, 116], dtype=uint8)),
#  ('airplane', array([224, 229, 232, ..., 235, 216, 208], dtype=uint8)),
#  ('airplane', array([192, 163,  89, ..., 130, 147, 126], dtype=uint8)),
#  ('airplane', array([133, 109,  97, ..., 101,  71,  60], dtype=uint8)),
#  ('airplane', array([238, 239, 237, ...,  84,  86, 104], dtype=uint8)),
#  ('airplane', array([178, 151, 124, ..., 130, 101,  74], dtype=uint8)),
#  ('airplane', array([248, 225, 180, ..., 250, 223, 173], dtype=uint8)),
#  ('airplane', array([104,  59,  25, ..., 174, 179, 182], dtype=uint8)),
#  ('airplane', array([169, 115,  62, ...,  41,  52,  49], dtype=uint8)),
#  ('airplane', array([56, 43, 29, ..., 96, 72, 30], dtype=uint8)),
#  ('airplane', array([108, 120, 114, ..., 107, 107, 119], dtype=uint8)),
#  ('airplane', array([188, 202, 198, ...,  80,  82,  90], dtype=uint8)),
#  ('airplane', array([198, 143, 100, ...,  97, 122,  96], dtype=uint8)),
#  ('airplane', array([210, 223, 201, ..., 254, 239, 213], dtype=uint8)),
#  ('airplane', array([179, 175, 187, ..., 109, 111, 105], dtype=uint8)),
#  ('airplane', array([241, 247, 246, ..., 180, 186, 199], dtype=uint8)),
#  ('airplane', array([144, 130, 111, ...,  63,  16,   0], dtype=uint8)),
#  ('airplane', array([106,  72,  59, ..., 110,  99, 102], dtype=uint8)),
#  ('airplane', array([243, 243, 243, ..., 187, 187, 187], dtype=uint8)),
#  ('airplane', array([240, 206, 170, ...,  89, 135, 146], dtype=uint8)),
#  ('airplane', array([136, 127, 114, ...,  44,  43,  52], dtype=uint8)),
#  ('airplane', array([116, 108, 109, ..., 171, 188, 191], dtype=uint8)),
#  ('airplane', array([202, 161, 138, ..., 255, 249, 255], dtype=uint8)),
#  ('airplane', array([228, 201, 181, ...,  71, 120, 104], dtype=uint8)),
#  ('airplane', array([245, 222, 190, ..., 143, 172, 177], dtype=uint8)),
#  ('airplane', array([254, 247, 255, ..., 255, 251, 255], dtype=uint8)),
#  ('airplane', array([67, 60, 63, ..., 59, 53, 58], dtype=uint8)),
#  ('airplane', array([132, 102,  75, ..., 162, 135,  98], dtype=uint8)),
#  ('airplane', array([204, 183, 161, ..., 153, 148, 145], dtype=uint8)),
#  ('airplane', array([194, 134, 110, ..., 132, 155, 177], dtype=uint8)),
#  ('airplane', array([188, 144,  81, ...,  92, 160, 167], dtype=uint8)),
#  ('airplane', array([228, 233, 232, ...,  89, 111, 116], dtype=uint8)),
#  ('airplane', array([245, 234, 212, ..., 206, 193, 179], dtype=uint8)),
#  ('airplane', array([175, 175, 175, ...,  62,  67,  68], dtype=uint8)),
#  ('airplane', array([159, 143, 114, ..., 146, 133, 111], dtype=uint8)),
#  ('airplane', array([178, 172, 173, ...,  25,  29,  48], dtype=uint8)),
#  ('airplane', array([203, 194, 161, ...,  84,  90,  41], dtype=uint8)),
#  ('airplane', array([186, 170, 181, ...,  81, 105, 127], dtype=uint8)),
#  ('airplane', array([208, 202, 189, ...,  41,  55,  77], dtype=uint8)),
#  ('airplane', array([223, 161,  91, ..., 238, 171, 110], dtype=uint8)),
#  ('airplane', array([126, 122, 133, ..., 142, 148, 177], dtype=uint8)),
#  ('airplane', array([75, 64, 56, ...,  5,  7,  1], dtype=uint8)),
#  ('airplane', array([156,  92,  51, ..., 235, 224, 186], dtype=uint8)),
#  ('airplane', array([171, 183, 141, ..., 228, 213, 211], dtype=uint8)),
#  ('airplane', array([223, 157, 132, ..., 237, 166, 139], dtype=uint8)),
#  ('airplane', array([194, 180, 174, ..., 147, 162, 171], dtype=uint8)),
#  ('airplane', array([142, 146, 135, ..., 130, 119, 122], dtype=uint8)),
#  ('airplane', array([237, 232, 211, ..., 233, 255, 253], dtype=uint8)),
#  ('airplane', array([246, 211, 191, ..., 137, 136, 138], dtype=uint8)),
#  ('airplane', array([109,  39,  15, ..., 118,  44,  16], dtype=uint8)),
#  ('airplane', array([  2,  11,  15, ..., 160, 136, 106], dtype=uint8)),
#  ('airplane', array([216, 216, 216, ..., 219, 219, 219], dtype=uint8)),
#  ('airplane', array([181, 181, 181, ..., 233, 233, 233], dtype=uint8)),
#  ('airplane', array([168, 212, 225, ..., 188, 218, 223], dtype=uint8)),
#  ('airplane', array([221, 190, 159, ..., 198, 201, 162], dtype=uint8)),
#  ('airplane', array([ 15, 134, 105, ...,  33, 119, 107], dtype=uint8)),
#  ('airplane', array([1, 0, 5, ..., 6, 5, 9], dtype=uint8)),
#  ('airplane', array([ 80, 104, 102, ..., 142, 138, 150], dtype=uint8)),
#  ('airplane', array([172, 120,  90, ..., 101,  82,  69], dtype=uint8)),
#  ('airplane', array([ 6, 15, 19, ..., 42, 42, 42], dtype=uint8)),
#  ('airplane', array([237, 234, 226, ...,  72,  81,  78], dtype=uint8)),
#  ('airplane', array([253, 175, 132, ..., 249, 179, 156], dtype=uint8)),
#  ('airplane', array([ 92, 147, 120, ..., 203, 225, 201], dtype=uint8)),
#  ('airplane', array([221, 167, 132, ..., 221, 167, 142], dtype=uint8)),
#  ('airplane', array([131, 134, 112, ...,  89, 110, 112], dtype=uint8)),
#  ('airplane', array([126,  99,  85, ...,  68,  73,  76], dtype=uint8)),
#  ('airplane', array([17, 24, 11, ...,  8, 19, 16], dtype=uint8)),
#  ('airplane', array([160, 169, 179, ..., 200, 207, 216], dtype=uint8)),
#  ('airplane', array([196, 174, 168, ...,  85,  74,  76], dtype=uint8)),
#  ('airplane', array([198, 147,  91, ..., 118,  84,  30], dtype=uint8)),
#  ('airplane', array([200, 195, 180, ..., 215, 216, 206], dtype=uint8)),
#  ('airplane', array([94, 40, 23, ..., 35, 47, 81], dtype=uint8)),
#  ('airplane', array([223, 138,  90, ..., 129, 151, 169], dtype=uint8)),
#  ('airplane', array([243, 226, 217, ..., 229, 242, 255], dtype=uint8)),
#  ('airplane', array([202, 166, 118, ..., 230, 231, 227], dtype=uint8)),
#  ('airplane', array([15,  1,  0, ..., 16,  9,  0], dtype=uint8)),
#  ('airplane', array([187, 187, 187, ..., 140, 140, 140], dtype=uint8)),
#  ('airplane', array([209, 174, 148, ...,  63,  67,  56], dtype=uint8)),
#  ('airplane', array([209, 148, 114, ..., 163, 182, 179], dtype=uint8)),
#  ('airplane', array([247, 234, 226, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([0, 5, 4, ..., 0, 0, 9], dtype=uint8)),
#  ('airplane', array([ 73, 106, 102, ...,  75, 107, 142], dtype=uint8)),
#  ('airplane', array([247, 211, 151, ..., 144, 161, 152], dtype=uint8)),
#  ('airplane', array([151, 159, 188, ..., 179, 206, 233], dtype=uint8)),
#  ('airplane', array([187, 182, 179, ..., 173, 157, 150], dtype=uint8)),
#  ('airplane', array([207,  97,  39, ..., 181,  89,  36], dtype=uint8)),
#  ('airplane', array([226, 234, 241, ..., 177, 199, 211], dtype=uint8)),
#  ('airplane', array([ 96,  91,  92, ..., 141, 123, 122], dtype=uint8)),
#  ('airplane', array([242, 212, 207, ..., 167, 108,  89], dtype=uint8)),
#  ('airplane', array([252, 245, 242, ..., 240, 238, 244], dtype=uint8)),
#  ('airplane', array([138, 121,  95, ...,  80,  80,  74], dtype=uint8)),
#  ('airplane', array([217, 185,  36, ..., 255, 251, 234], dtype=uint8)),
#  ('airplane', array([ 24,  50,  67, ..., 108, 129, 144], dtype=uint8)),
#  ('airplane', array([234, 137,  23, ..., 255, 156,  54], dtype=uint8)),
#  ('airplane', array([216, 139,   0, ..., 226, 131,   4], dtype=uint8)),
#  ('airplane', array([232, 232, 238, ...,  62, 186, 194], dtype=uint8)),
#  ('airplane', array([232, 225, 222, ..., 149, 129, 124], dtype=uint8)),
#  ('airplane', array([224, 131, 116, ..., 127,  89,  71], dtype=uint8)),
#  ('airplane', array([201, 211, 205, ..., 114, 181, 166], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 255, 252, 255], dtype=uint8)),
#  ('airplane', array([251, 251, 251, ..., 255, 255, 248], dtype=uint8)),
#  ('airplane', array([141, 113,  53, ..., 153, 101,  41], dtype=uint8)),
#  ('airplane', array([ 99,  64,  51, ..., 109,  79,  50], dtype=uint8)),
#  ('airplane', array([178, 114,  84, ..., 230, 194, 124], dtype=uint8)),
#  ('airplane', array([255, 255, 230, ..., 255, 234, 207], dtype=uint8)),
#  ('airplane', array([ 85, 126, 135, ...,  16,  64,  68], dtype=uint8)),
#  ('airplane', array([225, 218, 209, ..., 223, 229, 224], dtype=uint8)),
#  ('airplane', array([152, 102,  30, ..., 211, 202, 188], dtype=uint8)),
#  ('airplane', array([ 93,  37,  20, ..., 131,  96,  82], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([165, 165, 165, ..., 195, 195, 195], dtype=uint8)),
#  ('airplane', array([141, 138,  87, ...,  96, 138, 127], dtype=uint8)),
#  ('airplane', array([213, 199, 181, ...,  42,  34,  34], dtype=uint8)),
#  ('airplane', array([245, 245, 245, ..., 242, 242, 242], dtype=uint8)),
#  ('airplane', array([65, 60, 62, ..., 58, 53, 62], dtype=uint8)),
#  ('airplane', array([ 51,  68,  57, ..., 130, 142, 148], dtype=uint8)),
#  ('airplane', array([204, 208, 209, ..., 187, 172, 163], dtype=uint8)),
#  ('airplane', array([234, 222, 186, ..., 102, 153, 115], dtype=uint8)),
#  ('airplane', array([221, 222, 218, ..., 120, 101,  26], dtype=uint8)),
#  ('airplane', array([210, 210, 210, ..., 119, 119, 119], dtype=uint8)),
#  ('airplane', array([159, 160, 158, ...,   0,  10,   1], dtype=uint8)),
#  ('airplane', array([213, 174, 146, ..., 158, 114, 115], dtype=uint8)),
#  ('airplane', array([242, 252, 246, ...,  87, 105, 116], dtype=uint8)),
#  ('airplane', array([193, 191, 191, ..., 179, 195, 208], dtype=uint8)),
#  ('airplane', array([17, 59, 71, ...,  0, 55, 79], dtype=uint8)),
#  ('airplane', array([119,  94,  60, ..., 109,  97,  57], dtype=uint8)),
#  ('airplane', array([250, 247, 232, ...,  86,  77,  40], dtype=uint8)),
#  ('airplane', array([162, 132,  83, ..., 255, 255, 254], dtype=uint8)),
#  ('airplane', array([138,  88,  68, ..., 137,  84,  74], dtype=uint8)),
#  ('airplane', array([225, 224, 198, ..., 162, 163, 121], dtype=uint8)),
#  ('airplane', array([220, 221, 212, ...,  58, 111, 108], dtype=uint8)),
#  ('airplane', array([214, 192, 174, ..., 193, 191, 181], dtype=uint8)),
#  ('airplane', array([255, 254, 255, ..., 255, 255, 248], dtype=uint8)),
#  ('airplane', array([244, 237, 242, ..., 251, 222, 225], dtype=uint8)),
#  ('airplane', array([209, 161, 103, ..., 130, 112, 113], dtype=uint8)),
#  ('airplane', array([185, 129,  88, ...,  48,  88,  70], dtype=uint8)),
#  ('airplane', array([193, 173, 115, ...,  92,  65,  31], dtype=uint8)),
#  ('airplane', array([218, 199, 166, ...,  53,  41,  41], dtype=uint8)),
#  ('airplane', array([210, 204, 205, ..., 138, 168, 179], dtype=uint8)),
#  ('airplane', array([213, 196, 187, ..., 229, 217, 215], dtype=uint8)),
#  ('airplane', array([245, 234, 142, ..., 182, 206, 204], dtype=uint8)),
#  ('airplane', array([250, 250, 250, ..., 255, 254, 255], dtype=uint8)),
#  ('airplane', array([213, 168, 130, ..., 102, 157, 194], dtype=uint8)),
#  ('airplane', array([204, 159,  92, ..., 162, 158, 140], dtype=uint8)),
#  ('airplane', array([236, 240, 241, ..., 237, 241, 242], dtype=uint8)),
#  ('airplane', array([  0,  42, 117, ...,   0,  11, 111], dtype=uint8)),
#  ('airplane', array([164, 168, 127, ..., 153, 149, 120], dtype=uint8)),
#  ('airplane', array([255, 255, 248, ..., 255, 255, 246], dtype=uint8)),
#  ('airplane', array([201, 158, 139, ...,  57,  94,  86], dtype=uint8)),
#  ('airplane', array([165, 157, 150, ..., 149, 135, 137], dtype=uint8)),
#  ('airplane', array([253, 253, 253, ..., 251, 251, 251], dtype=uint8)),
#  ('airplane', array([208, 189, 162, ...,  44, 123, 144], dtype=uint8)),
#  ('airplane', array([235, 246, 255, ..., 245, 243, 242], dtype=uint8)),
#  ('airplane', array([180, 150, 109, ..., 251, 255, 244], dtype=uint8)),
#  ('airplane', array([255, 249, 255, ..., 255, 255, 254], dtype=uint8)),
#  ('airplane', array([245, 226, 218, ..., 123, 120, 129], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ...,  97,  97,  97], dtype=uint8)),
#  ('airplane', array([171, 193, 198, ..., 156, 208, 208], dtype=uint8)),
#  ('airplane', array([129, 133, 128, ...,  22,  63,  48], dtype=uint8)),
#  ('airplane', array([167, 132, 136, ..., 161, 132, 128], dtype=uint8)),
#  ('airplane', array([138, 136, 128, ..., 153, 152, 142], dtype=uint8)),
#  ('airplane', array([217, 188, 157, ..., 180, 162, 131], dtype=uint8)),
#  ('airplane', array([105,  81, 129, ...,  92,  38,  31], dtype=uint8)),
#  ('airplane', array([162, 110,  40, ..., 166, 202, 212], dtype=uint8)),
#  ('airplane', array([214, 205, 192, ..., 186, 187, 191], dtype=uint8)),
#  ('airplane', array([19, 62, 53, ..., 15, 49, 38], dtype=uint8)),
#  ('airplane', array([199, 133,  92, ..., 101, 109, 116], dtype=uint8)),
#  ('airplane', array([106,  96, 109, ..., 106, 104, 116], dtype=uint8)),
#  ('airplane', array([122, 122, 122, ...,  53,  53,  53], dtype=uint8)),
#  ('airplane', array([225, 216, 213, ..., 215, 226, 224], dtype=uint8)),
#  ('airplane', array([54, 95, 80, ..., 71, 79, 49], dtype=uint8)),
#  ('airplane', array([146,  87,   8, ..., 223, 213, 183], dtype=uint8)),
#  ('airplane', array([79, 63, 50, ..., 69, 86, 89], dtype=uint8)),
#  ('airplane', array([206, 189, 186, ..., 165, 150, 148], dtype=uint8)),
#  ('airplane', array([235, 230, 232, ..., 236, 215, 223], dtype=uint8)),
#  ('airplane', array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)),
#  ('airplane', array([250, 158, 115, ..., 245, 177, 134], dtype=uint8)),
#  ('airplane', array([216, 210, 143, ..., 215, 229, 218], dtype=uint8)),
#  ('airplane', array([255, 237, 229, ..., 232, 220, 214], dtype=uint8)),
#  ('airplane', array([158, 111,  97, ...,  42,  26,  19], dtype=uint8)),
#  ('airplane', array([213, 199, 201, ...,  83,  70,  78], dtype=uint8)),
#  ('airplane', array([115, 142, 116, ..., 104, 117,  93], dtype=uint8)),
#  ('airplane', array([155,  84,   0, ..., 165,  96,   0], dtype=uint8)),
#  ('airplane', array([253, 255, 255, ..., 246, 251, 250], dtype=uint8)),
#  ('airplane', array([150, 150, 150, ..., 119, 119, 119], dtype=uint8)),
#  ('airplane', array([227, 155, 131, ..., 213, 172, 127], dtype=uint8)),
#  ('airplane', array([242, 214, 160, ..., 253, 242, 234], dtype=uint8)),
#  ('airplane', array([215, 209, 196, ..., 111, 118, 115], dtype=uint8)),
#  ('airplane', array([120,  99, 101, ...,  86,  79,  64], dtype=uint8)),
#  ('airplane', array([ 73, 114, 129, ..., 166, 170, 171], dtype=uint8)),
#  ('airplane', array([199, 168, 135, ...,  89,  69,  44], dtype=uint8)),
#  ('airplane', array([145,  83,  37, ...,  22,  43,  75], dtype=uint8)),
#  ('airplane', array([243, 202, 177, ..., 251, 247, 236], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 204, 204, 204], dtype=uint8)),
#  ('airplane', array([246, 228, 187, ...,  92, 124, 129], dtype=uint8)),
#  ('airplane', array([226, 215, 153, ..., 203, 199,  26], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 255, 255, 251], dtype=uint8)),
#  ('airplane', array([155, 158, 149, ..., 197, 177, 166], dtype=uint8)),
#  ('airplane', array([ 84, 102, 113, ..., 132, 130, 129], dtype=uint8)),
#  ('airplane', array([ 92,  91,  81, ...,  76, 124, 126], dtype=uint8)),
#  ('airplane', array([174, 117,  66, ...,  70,  86,  39], dtype=uint8)),
#  ('airplane', array([200, 195, 164, ..., 191, 186, 155], dtype=uint8)),
#  ('airplane', array([205, 186, 178, ..., 179, 146, 137], dtype=uint8)),
#  ('airplane', array([124,  92,  73, ..., 144, 105,  77], dtype=uint8)),
#  ('airplane', array([127,   0,  16, ..., 128,   4,   4], dtype=uint8)),
#  ('airplane', array([255, 187, 164, ..., 243, 168, 142], dtype=uint8)),
#  ('airplane', array([ 93, 124, 127, ...,  61,  72,  64], dtype=uint8)),
#  ('airplane', array([229, 214, 198, ..., 229, 206, 191], dtype=uint8)),
#  ('airplane', array([255, 254, 255, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([239, 213, 183, ..., 105, 111, 122], dtype=uint8)),
#  ('airplane', array([133, 154, 145, ...,  35,  47,  57], dtype=uint8)),
#  ('airplane', array([216, 218, 212, ..., 135, 123, 117], dtype=uint8)),
#  ('airplane', array([189, 157, 116, ..., 210, 166, 135], dtype=uint8)),
#  ('airplane', array([184, 151, 158, ...,  73,  91, 102], dtype=uint8)),
#  ('airplane', array([187, 206, 211, ...,  81,  77,  72], dtype=uint8)),
#  ('airplane', array([189, 155, 162, ..., 154, 125, 141], dtype=uint8)),
#  ('airplane', array([131, 116,  97, ...,  85, 124, 133], dtype=uint8)),
#  ('airplane', array([58, 51, 54, ..., 61, 53, 60], dtype=uint8)),
#  ('airplane', array([189, 151,  87, ..., 174, 195, 210], dtype=uint8)),
#  ('airplane', array([171, 130,  75, ...,  94,  75,  18], dtype=uint8)),
#  ('airplane', array([213, 218, 216, ...,  83,  89,  78], dtype=uint8)),
#  ('airplane', array([225, 223, 222, ..., 165, 170, 179], dtype=uint8)),
#  ('airplane', array([226, 212, 214, ..., 223, 209, 213], dtype=uint8)),
#  ('airplane', array([214, 159, 168, ..., 197, 160, 194], dtype=uint8)),
#  ('airplane', array([250, 225, 151, ...,  38,  36,  35], dtype=uint8)),
#  ('airplane', array([250, 249, 228, ..., 199, 232, 241], dtype=uint8)),
#  ('airplane', array([255, 255, 211, ..., 111, 110, 106], dtype=uint8)),
#  ('airplane', array([152, 150, 142, ...,  51,  90,  92], dtype=uint8)),
#  ('airplane', array([134,  94,  99, ..., 179, 175, 180], dtype=uint8)),
#  ('airplane', array([10, 10, 10, ...,  0,  0,  0], dtype=uint8)),
#  ('airplane', array([238, 208, 183, ...,  31,  14,  35], dtype=uint8)),
#  ('airplane', array([60, 61, 59, ..., 65, 75, 63], dtype=uint8)),
#  ('airplane', array([232, 202, 145, ...,  37,  36,  45], dtype=uint8)),
#  ('airplane', array([203, 206, 184, ...,  14,  13,  15], dtype=uint8)),
#  ('airplane', array([195, 187, 180, ...,  34,  89,  86], dtype=uint8)),
#  ('airplane', array([255, 252, 249, ..., 122, 126, 137], dtype=uint8)),
#  ('airplane', array([255, 254, 255, ...,  85, 166, 163], dtype=uint8)),
#  ('airplane', array([255, 252, 251, ...,  67,  77,  71], dtype=uint8)),
#  ('airplane', array([251, 230, 192, ..., 136, 141, 150], dtype=uint8)),
#  ('airplane', array([122, 114,  97, ...,  40,  37,  46], dtype=uint8)),
#  ('airplane', array([228, 219, 216, ...,  91, 112, 114], dtype=uint8)),
#  ('airplane', array([190, 135,  92, ..., 164, 130,  84], dtype=uint8)),
#  ('airplane', array([203, 203, 203, ..., 228, 228, 228], dtype=uint8)),
#  ('airplane', array([220, 245, 249, ..., 134, 149, 158], dtype=uint8)),
#  ('airplane', array([108,  88,  77, ...,  62,  67,  82], dtype=uint8)),
#  ('airplane', array([174, 147, 120, ..., 173, 144, 117], dtype=uint8)),
#  ('airplane', array([145, 147, 147, ..., 149, 138, 140], dtype=uint8)),
#  ('airplane', array([144,  90,  29, ..., 150,  83,  34], dtype=uint8)),
#  ('airplane', array([ 89, 106,  97, ...,  51,  77,  63], dtype=uint8)),
#  ('airplane', array([186, 208, 190, ..., 194, 225, 226], dtype=uint8)),
#  ('airplane', array([184, 202, 209, ...,  49,  39,  22], dtype=uint8)),
#  ('airplane', array([0, 0, 7, ..., 2, 0, 0], dtype=uint8)),
#  ('airplane', array([ 3,  4,  2, ..., 69, 66, 58], dtype=uint8)),
#  ('airplane', array([198, 197, 193, ..., 148, 160, 170], dtype=uint8)),
#  ('airplane', array([195, 174, 159, ..., 190, 164, 148], dtype=uint8)),
#  ('airplane', array([147, 119, 132, ..., 117, 106, 114], dtype=uint8)),
#  ('airplane', array([150,  85,  84, ..., 123,  94,  85], dtype=uint8)),
#  ('airplane', array([255, 228, 193, ..., 255, 235, 207], dtype=uint8)),
#  ('airplane', array([189, 152,  92, ...,   7,  11,   6], dtype=uint8)),
#  ('airplane', array([139, 104,  54, ...,  49,  40,  13], dtype=uint8)),
#  ('airplane', array([252, 252, 240, ..., 147, 136, 138], dtype=uint8)),
#  ('airplane', array([65, 60, 62, ..., 68, 58, 64], dtype=uint8)),
#  ('airplane', array([247, 247, 247, ..., 210, 210, 210], dtype=uint8)),
#  ('airplane', array([172, 171, 173, ..., 185, 184, 186], dtype=uint8)),
#  ('airplane', array([208, 218, 212, ..., 166, 192, 204], dtype=uint8)),
#  ('airplane', array([206, 154, 117, ..., 209, 151,  99], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 126, 113, 139], dtype=uint8)),
#  ('airplane', array([221, 207, 208, ..., 183, 186, 170], dtype=uint8)),
#  ('airplane', array([140, 124, 118, ...,  83,  99, 111], dtype=uint8)),
#  ('airplane', array([165, 178, 186, ..., 201, 206, 209], dtype=uint8)),
#  ('airplane', array([252, 248, 247, ..., 152, 161, 158], dtype=uint8)),
#  ('airplane', array([227, 223, 212, ..., 255, 254, 254], dtype=uint8)),
#  ('airplane', array([246, 240, 235, ..., 228, 212, 199], dtype=uint8)),
#  ('airplane', array([253, 253, 253, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([140, 117, 121, ..., 168, 154, 158], dtype=uint8)),
#  ('airplane', array([147, 130, 127, ..., 185, 170, 168], dtype=uint8)),
#  ('airplane', array([180, 175, 174, ..., 167, 162, 163], dtype=uint8)),
#  ('airplane', array([217, 186, 187, ..., 235, 204, 213], dtype=uint8)),
#  ('airplane', array([126,  59,  32, ..., 155, 154, 163], dtype=uint8)),
#  ('airplane', array([217, 188, 137, ..., 224, 217, 214], dtype=uint8)),
#  ('airplane', array([217, 161, 142, ..., 224, 155, 106], dtype=uint8)),
#  ('airplane', array([253, 255, 255, ..., 250, 250, 250], dtype=uint8)),
#  ('airplane', array([177, 184, 179, ...,   6,  90, 132], dtype=uint8)),
#  ('airplane', array([138, 122,  76, ..., 181, 160, 145], dtype=uint8)),
#  ('airplane', array([186, 174, 162, ..., 208, 202, 191], dtype=uint8)),
#  ('airplane', array([221, 180, 147, ..., 114, 123, 132], dtype=uint8)),
#  ('airplane', array([255, 247, 254, ...,  94, 111, 154], dtype=uint8)),
#  ('airplane', array([119,  78,  45, ..., 213, 193, 138], dtype=uint8)),
#  ('airplane', array([183, 179, 174, ..., 139, 121, 104], dtype=uint8)),
#  ('airplane', array([152,  81,  17, ..., 188, 154, 184], dtype=uint8)),
#  ('airplane', array([224, 115,  94, ..., 127,  58,  48], dtype=uint8)),
#  ('airplane', array([251, 249, 248, ..., 108,  83,  81], dtype=uint8)),
#  ('airplane', array([151, 130, 108, ..., 136, 124, 118], dtype=uint8)),
#  ('airplane', array([243, 170, 138, ..., 202, 161, 129], dtype=uint8)),
#  ('airplane', array([206, 174, 108, ..., 204, 186, 185], dtype=uint8)),
#  ('airplane', array([174, 152, 141, ..., 161, 182, 204], dtype=uint8)),
#  ('airplane', array([252, 161, 110, ..., 253, 165,  94], dtype=uint8)),
#  ('airplane', array([162, 110, 103, ...,  71,  59,  57], dtype=uint8)),
#  ('airplane', array([245, 250, 255, ...,  94,  87,  78], dtype=uint8)),
#  ('airplane', array([255, 248, 239, ...,  44,  52,  51], dtype=uint8)),
#  ('airplane', array([252, 254, 254, ..., 247, 250, 255], dtype=uint8)),
#  ('airplane', array([184, 170, 128, ...,  29,  20,  16], dtype=uint8)),
#  ('airplane', array([180,  87,  54, ..., 104, 135, 174], dtype=uint8)),
#  ('airplane', array([207, 164,  97, ...,  58,  82,  82], dtype=uint8)),
#  ('airplane', array([242, 219, 187, ...,  69,  88,  55], dtype=uint8)),
#  ('airplane', array([167, 167, 167, ..., 157, 153, 148], dtype=uint8)),
#  ('airplane', array([213, 174, 152, ..., 144, 112,  93], dtype=uint8)),
#  ('airplane', array([242,  95,  45, ..., 198, 106,  41], dtype=uint8)),
#  ('airplane', array([164,  95,  26, ..., 163,  97,  46], dtype=uint8)),
#  ('airplane', array([37, 80, 69, ..., 21, 59, 53], dtype=uint8)),
#  ('airplane', array([115,  74,  52, ..., 140,  96,  65], dtype=uint8)),
#  ('airplane', array([178, 136,  91, ..., 234, 235, 239], dtype=uint8)),
#  ('airplane', array([171, 170, 179, ..., 190, 191, 187], dtype=uint8)),
#  ('airplane', array([144, 131, 117, ..., 255, 255, 254], dtype=uint8)),
#  ('airplane', array([201, 187, 198, ..., 184, 194, 211], dtype=uint8)),
#  ('airplane', array([184, 182, 188, ..., 198, 124, 100], dtype=uint8)),
#  ('airplane', array([247, 237, 250, ...,  15,  31,  43], dtype=uint8)),
#  ('airplane', array([231, 134, 166, ..., 171, 151, 104], dtype=uint8)),
#  ('airplane', array([235, 239, 198, ..., 147, 227, 228], dtype=uint8)),
#  ('airplane', array([218, 207, 193, ..., 231, 220, 206], dtype=uint8)),
#  ('airplane', array([ 54,  46,  29, ..., 189, 212, 208], dtype=uint8)),
#  ('airplane', array([229, 193, 155, ..., 228, 200, 165], dtype=uint8)),
#  ('airplane', array([147, 147, 147, ...,  34,  57,  43], dtype=uint8)),
#  ('airplane', array([158, 123,  97, ...,  86,  65,  44], dtype=uint8)),
#  ('airplane', array([ 93, 110, 129, ...,  88, 103, 112], dtype=uint8)),
#  ('airplane', array([253, 253, 253, ...,  65,  65,  65], dtype=uint8)),
#  ('airplane', array([164,  82,  34, ...,  12,  58,  46], dtype=uint8)),
#  ('airplane', array([163,  97,  49, ..., 124,  98,  51], dtype=uint8)),
#  ('airplane', array([ 35,  43,  26, ...,  97, 142, 139], dtype=uint8)),
#  ('airplane', array([248, 248, 248, ..., 201, 201, 201], dtype=uint8)),
#  ('airplane', array([153, 144, 131, ..., 176, 149, 105], dtype=uint8)),
#  ('airplane', array([252, 249, 245, ..., 151, 128, 113], dtype=uint8)),
#  ('airplane', array([119,  79,  67, ...,  77,  78,  74], dtype=uint8)),
#  ('airplane', array([134, 137, 141, ..., 131, 134, 125], dtype=uint8)),
#  ('airplane', array([129,  75,  15, ...,  83,  51,  38], dtype=uint8)),
#  ('airplane', array([243, 224, 191, ..., 170, 179, 139], dtype=uint8)),
#  ('airplane', array([227, 195, 159, ..., 157, 131,  91], dtype=uint8)),
#  ('airplane', array([143,  81,  40, ..., 115, 109,  98], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 125, 125, 125], dtype=uint8)),
#  ('airplane', array([204, 178, 124, ..., 158, 185, 189], dtype=uint8)),
#  ('airplane', array([238, 221, 218, ...,  61,  50,  46], dtype=uint8)),
#  ('airplane', array([180, 165, 132, ..., 174, 180, 169], dtype=uint8)),
#  ('airplane', array([154, 137,  74, ..., 135, 129,  94], dtype=uint8)),
#  ('airplane', array([208, 132,  80, ..., 210, 153,  84], dtype=uint8)),
#  ('airplane', array([150, 167, 163, ..., 255, 250, 243], dtype=uint8)),
#  ('airplane', array([164, 126,  24, ..., 123, 162, 160], dtype=uint8)),
# ...
#  ('airplane', array([216, 148,  71, ...,  69,  69,  51], dtype=uint8)),
#  ('airplane', array([190, 172, 141, ..., 159, 168, 158], dtype=uint8)),
#  ('airplane', array([ 75, 118, 175, ...,  17,  10,   7], dtype=uint8)),
#  ('airplane', array([124, 124, 124, ..., 212, 212, 212], dtype=uint8)),
#  ('airplane', array([204, 167, 163, ..., 207, 172, 162], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([41, 78, 68, ..., 26, 60, 54], dtype=uint8)),
#  ('airplane', array([158, 127, 104, ...,  61,  68,  83], dtype=uint8)),
#  ('airplane', array([208, 148, 102, ..., 101,  86,  83], dtype=uint8)),
#  ('airplane', array([255, 250, 235, ..., 240, 241, 225], dtype=uint8)),
#  ('airplane', array([203, 218, 221, ..., 185, 182, 167], dtype=uint8)),
#  ('airplane', array([232, 230, 199, ..., 198, 192, 187], dtype=uint8)),
#  ('airplane', array([218, 207, 210, ..., 109, 121, 123], dtype=uint8)),
#  ('airplane', array([217, 165,  65, ..., 225, 166,  66], dtype=uint8)),
#  ('airplane', array([255, 246, 255, ..., 253, 255, 252], dtype=uint8)),
#  ('airplane', array([101,  66,  70, ..., 116,  90,  76], dtype=uint8)),
#  ('airplane', array([ 73,  36,  16, ..., 190, 189, 185], dtype=uint8)),
#  ('airplane', array([241, 155,  35, ..., 231, 154,  32], dtype=uint8)),
#  ('airplane', array([51, 62, 46, ..., 32, 52, 29], dtype=uint8)),
#  ('airplane', array([249, 254, 252, ..., 254, 248, 253], dtype=uint8)),
#  ('airplane', array([255, 253, 252, ...,  14,  20,  31], dtype=uint8)),
#  ('airplane', array([ 37,  45,  38, ..., 217, 219, 219], dtype=uint8)),
#  ('airplane', array([159, 156, 148, ..., 157, 164, 151], dtype=uint8)),
#  ('airplane', array([194, 148, 107, ..., 187, 149, 107], dtype=uint8)),
#  ('airplane', array([219, 187, 164, ..., 217, 187, 170], dtype=uint8)),
#  ('airplane', array([198, 197, 193, ..., 204, 202, 224], dtype=uint8)),
#  ('airplane', array([241, 231, 207, ..., 215, 207, 177], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ...,   3,   3,   3], dtype=uint8)),
#  ('airplane', array([196, 196, 196, ..., 245, 245, 245], dtype=uint8)),
#  ('airplane', array([229, 224, 225, ..., 238, 238, 238], dtype=uint8)),
#  ('airplane', array([ 93,  78, 105, ...,  45,  63, 100], dtype=uint8)),
#  ('airplane', array([241, 240, 226, ..., 157, 159, 153], dtype=uint8)),
#  ('airplane', array([255, 255, 252, ..., 255, 255, 250], dtype=uint8)),
#  ('airplane', array([ 72,  74,  84, ..., 103, 104, 108], dtype=uint8)),
#  ('airplane', array([187, 151, 157, ...,  60,  91, 170], dtype=uint8)),
#  ('airplane', array([214, 222, 229, ..., 185, 197, 185], dtype=uint8)),
#  ('airplane', array([ 67,  87, 104, ...,  61,  62,  76], dtype=uint8)),
#  ('airplane', array([200, 181, 202, ..., 169, 154, 175], dtype=uint8)),
#  ('airplane', array([215, 130,  74, ...,  40,  60,  85], dtype=uint8)),
#  ('airplane', array([183, 149, 119, ...,  55,  50,  51], dtype=uint8)),
#  ('airplane', array([254, 238, 215, ...,  36,  19,  56], dtype=uint8)),
#  ('airplane', array([119, 105,  99, ..., 111, 102,  98], dtype=uint8)),
#  ('airplane', array([220, 176, 152, ..., 166, 195, 186], dtype=uint8)),
#  ('airplane', array([237, 159, 113, ..., 255, 200, 194], dtype=uint8)),
#  ('airplane', array([233, 239, 238, ...,  76,  93,  96], dtype=uint8)),
#  ('airplane', array([199, 194, 195, ...,  97, 112, 114], dtype=uint8)),
#  ('airplane', array([122,  85,  41, ..., 105, 134, 139], dtype=uint8)),
#  ('airplane', array([107,  75,  70, ..., 170, 174, 185], dtype=uint8)),
#  ('airplane', array([249, 254, 253, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([213, 166, 135, ...,  96, 111, 127], dtype=uint8)),
#  ('airplane', array([255, 247, 240, ..., 255, 247, 255], dtype=uint8)),
#  ('airplane', array([255, 255, 254, ..., 242, 240, 239], dtype=uint8)),
#  ('airplane', array([206, 203, 195, ..., 215, 220, 221], dtype=uint8)),
#  ('airplane', array([183, 124, 105, ..., 212, 158, 123], dtype=uint8)),
#  ('airplane', array([187, 182, 161, ..., 149, 143, 166], dtype=uint8)),
#  ('airplane', array([201, 176, 144, ..., 222, 178, 154], dtype=uint8)),
#  ('airplane', array([177, 149, 119, ..., 124,  94,  67], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 251, 254, 252], dtype=uint8)),
#  ('airplane', array([238, 240, 198, ..., 104, 128, 120], dtype=uint8)),
#  ('airplane', array([120, 111, 102, ..., 151, 138, 146], dtype=uint8)),
#  ('airplane', array([132, 115,  88, ..., 112,  97,  94], dtype=uint8)),
#  ('airplane', array([246, 220, 213, ...,  53,  80,  76], dtype=uint8)),
#  ('airplane', array([238, 234, 229, ...,  67,  62,  61], dtype=uint8)),
#  ('airplane', array([196, 162, 149, ..., 122, 116, 111], dtype=uint8)),
#  ('airplane', array([ 30,   2, 179, ...,  60,   0, 188], dtype=uint8)),
#  ('airplane', array([158,  78,  55, ..., 180, 115,  77], dtype=uint8)),
#  ('airplane', array([204, 183, 151, ...,  78, 124, 142], dtype=uint8)),
#  ('airplane', array([187, 154, 134, ..., 146, 139, 144], dtype=uint8)),
#  ('airplane', array([234, 229, 226, ...,  64,  31,  16], dtype=uint8)),
#  ('airplane', array([195, 205, 205, ..., 203, 209, 208], dtype=uint8)),
#  ('airplane', array([241, 207, 191, ..., 113, 106,  91], dtype=uint8)),
#  ('airplane', array([198, 198, 198, ...,  73,  73,  73], dtype=uint8)),
#  ('airplane', array([189, 197, 167, ..., 140, 132,  85], dtype=uint8)),
#  ('airplane', array([202, 165, 143, ..., 253, 254, 255], dtype=uint8)),
#  ('airplane', array([149, 141, 124, ..., 143, 128, 109], dtype=uint8)),
#  ('airplane', array([198, 152, 121, ...,  67, 138, 121], dtype=uint8)),
#  ('airplane', array([255, 192, 153, ..., 244, 213, 188], dtype=uint8)),
#  ('airplane', array([213, 203, 193, ..., 215, 217, 205], dtype=uint8)),
#  ('airplane', array([ 59,  79,  66, ..., 144, 169, 171], dtype=uint8)),
#  ('airplane', array([141, 182, 191, ...,  88, 114, 121], dtype=uint8)),
#  ('airplane', array([ 76,  26,   0, ..., 186,  85,  33], dtype=uint8)),
#  ('airplane', array([204, 182, 171, ..., 246, 234, 228], dtype=uint8)),
#  ('airplane', array([153, 145, 155, ..., 123, 126, 157], dtype=uint8)),
#  ('airplane', array([163, 158, 155, ...,  66,  56,  46], dtype=uint8)),
#  ('airplane', array([ 98, 100, 111, ..., 107, 115, 145], dtype=uint8)),
#  ('airplane', array([220, 180, 138, ..., 238, 196, 154], dtype=uint8)),
#  ('airplane', array([201, 177, 171, ...,  59, 135, 117], dtype=uint8)),
#  ('airplane', array([203, 204, 208, ...,  67, 128, 142], dtype=uint8)),
#  ('airplane', array([229, 196, 151, ..., 179, 179, 195], dtype=uint8)),
#  ('airplane', array([243, 194, 172, ..., 250, 173, 141], dtype=uint8)),
#  ('airplane', array([234, 209, 205, ..., 222, 203, 198], dtype=uint8)),
#  ('airplane', array([206, 187, 174, ..., 186, 149, 115], dtype=uint8)),
#  ('airplane', array([239, 145,  72, ..., 121,  91, 104], dtype=uint8)),
#  ('airplane', array([232, 230, 229, ...,  67,  88,  89], dtype=uint8)),
#  ('airplane', array([85, 69, 27, ..., 63, 43, 38], dtype=uint8)),
#  ('airplane', array([ 26,  97, 101, ...,  15, 105, 112], dtype=uint8)),
#  ('airplane', array([249, 209, 144, ..., 163, 179, 178], dtype=uint8)),
#  ('airplane', array([217, 201, 202, ..., 127, 183, 218], dtype=uint8)),
#  ('airplane', array([238, 255, 252, ..., 231, 244, 252], dtype=uint8)),
#  ('airplane', array([174, 109,  34, ..., 106,  90,  67], dtype=uint8)),
#  ('airplane', array([170, 137, 144, ...,  66,  50,  37], dtype=uint8)),
#  ('airplane', array([195, 174, 166, ..., 120, 137, 158], dtype=uint8)),
#  ('airplane', array([231, 214, 193, ..., 234, 221, 205], dtype=uint8)),
#  ('airplane', array([233, 229, 124, ...,  15,   1,   5], dtype=uint8)),
#  ('airplane', array([144, 128,  99, ..., 102, 103, 101], dtype=uint8)),
#  ('airplane', array([213, 169, 115, ..., 155, 168, 170], dtype=uint8)),
#  ('airplane', array([190, 190, 184, ...,  60, 120, 156], dtype=uint8)),
#  ('airplane', array([253, 254, 252, ..., 204, 212, 201], dtype=uint8)),
#  ('airplane', array([120, 151, 148, ..., 105,  87, 100], dtype=uint8)),
#  ('airplane', array([220, 164, 123, ..., 221, 173, 131], dtype=uint8)),
#  ('airplane', array([178, 113,   0, ..., 237, 230, 227], dtype=uint8)),
#  ('airplane', array([163, 153, 146, ...,  16,  80,  75], dtype=uint8)),
#  ('airplane', array([122, 107,  98, ...,  60,  30,  25], dtype=uint8)),
#  ('airplane', array([167, 117,  87, ..., 112,  85,  58], dtype=uint8)),
#  ('airplane', array([214, 172, 135, ...,  77,  73,  68], dtype=uint8)),
#  ('airplane', array([203, 137,  59, ..., 158,  83,   0], dtype=uint8)),
#  ('airplane', array([215, 215, 215, ..., 235, 235, 235], dtype=uint8)),
#  ('airplane', array([177, 177, 177, ..., 111, 111, 111], dtype=uint8)),
#  ('airplane', array([235, 188, 150, ..., 197, 189, 199], dtype=uint8)),
#  ('airplane', array([178, 187, 197, ..., 168, 183, 199], dtype=uint8)),
#  ('airplane', array([142, 187, 221, ..., 123, 180, 202], dtype=uint8)),
#  ('airplane', array([190, 180, 203, ..., 133, 146, 160], dtype=uint8)),
#  ('airplane', array([210, 196, 232, ..., 171, 178, 175], dtype=uint8)),
#  ('airplane', array([106,  19,  22, ...,  65,  14,  11], dtype=uint8)),
#  ('airplane', array([200, 188, 188, ..., 210, 196, 198], dtype=uint8)),
#  ('airplane', array([87, 41, 24, ..., 42, 49, 66], dtype=uint8)),
#  ('airplane', array([226, 201, 167, ..., 119,  69,  33], dtype=uint8)),
#  ('airplane', array([240, 225, 199, ..., 173, 165, 172], dtype=uint8)),
#  ('airplane', array([219, 172, 141, ..., 224, 186, 154], dtype=uint8)),
#  ('airplane', array([241, 229, 225, ..., 170, 178, 185], dtype=uint8)),
#  ('airplane', array([  0,  76, 195, ...,  79, 195, 252], dtype=uint8)),
#  ('airplane', array([175, 159, 153, ..., 192, 200, 223], dtype=uint8)),
#  ('airplane', array([195, 172, 156, ...,  89,  80, 120], dtype=uint8)),
#  ('airplane', array([229, 226, 195, ...,  93, 127, 121], dtype=uint8)),
#  ('airplane', array([59, 52, 55, ..., 63, 49, 53], dtype=uint8)),
#  ('airplane', array([167, 130, 108, ...,  47,  86,  88], dtype=uint8)),
#  ('airplane', array([254, 255, 253, ...,  20,  60,  55], dtype=uint8)),
#  ('airplane', array([ 70, 124,  87, ...,  26,  84,  56], dtype=uint8)),
#  ('airplane', array([ 92, 136, 137, ..., 138, 136, 136], dtype=uint8)),
#  ('airplane', array([228, 117,  79, ..., 197, 176, 149], dtype=uint8)),
#  ('airplane', array([240, 215, 229, ..., 247, 234, 232], dtype=uint8)),
#  ('airplane', array([144, 143, 145, ..., 158, 165, 184], dtype=uint8)),
#  ('airplane', array([203, 160, 141, ..., 171, 185, 119], dtype=uint8)),
#  ('airplane', array([220, 168, 122, ..., 176, 187, 191], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([244, 204, 176, ...,  36,  16,  11], dtype=uint8)),
#  ('airplane', array([169, 120,  76, ..., 139, 103,  67], dtype=uint8)),
#  ('airplane', array([196, 185, 153, ...,  88, 105,  94], dtype=uint8)),
#  ('airplane', array([ 55,  84, 121, ...,  22,  46,  68], dtype=uint8)),
#  ('airplane', array([ 62, 142, 149, ...,  45, 128, 136], dtype=uint8)),
#  ('airplane', array([192, 147, 103, ..., 176, 141,  97], dtype=uint8)),
#  ('airplane', array([165, 156, 147, ..., 117, 139, 144], dtype=uint8)),
#  ('airplane', array([200, 145,  78, ...,  74,  75,  66], dtype=uint8)),
#  ('airplane', array([240, 191, 141, ..., 224, 188, 152], dtype=uint8)),
#  ('airplane', array([218, 154,  99, ..., 213, 165, 107], dtype=uint8)),
#  ('airplane', array([133, 134,  78, ..., 168, 169, 167], dtype=uint8)),
#  ('airplane', array([104, 102,  92, ...,  44,  97, 107], dtype=uint8)),
#  ('airplane', array([234, 223, 226, ...,  30,  77,  81], dtype=uint8)),
#  ('airplane', array([187, 190, 165, ..., 159, 185, 197], dtype=uint8)),
#  ('airplane', array([217, 204, 196, ...,  87, 116, 121], dtype=uint8)),
#  ('airplane', array([112, 109,  95, ...,  68,  76,  83], dtype=uint8)),
#  ('airplane', array([186, 110,  61, ..., 112, 126, 120], dtype=uint8)),
#  ('airplane', array([139,  93,  35, ..., 191, 178, 180], dtype=uint8)),
#  ('airplane', array([222, 155,  92, ...,  58, 106, 112], dtype=uint8)),
#  ('airplane', array([162, 124,  82, ...,  34,  75,  77], dtype=uint8)),
#  ('airplane', array([136,  81,  38, ..., 194,  84,  36], dtype=uint8)),
#  ('airplane', array([230, 193, 167, ...,  58, 106,  88], dtype=uint8)),
#  ('airplane', array([ 76,  69,  60, ..., 180, 204, 226], dtype=uint8)),
#  ('airplane', array([172, 187, 190, ..., 135, 178, 187], dtype=uint8)),
#  ('airplane', array([2, 2, 2, ..., 1, 1, 1], dtype=uint8)),
#  ('airplane', array([191, 187, 163, ..., 104, 161, 192], dtype=uint8)),
#  ('airplane', array([169, 131,  89, ..., 185, 153, 117], dtype=uint8)),
#  ('airplane', array([182, 138,  77, ..., 192, 163,  82], dtype=uint8)),
#  ('airplane', array([ 72, 114, 113, ...,  52, 106,  99], dtype=uint8)),
#  ('airplane', array([220, 146,  80, ..., 179, 141, 123], dtype=uint8)),
#  ('airplane', array([190, 162, 121, ...,   8,  12,  13], dtype=uint8)),
#  ('airplane', array([226, 195, 162, ..., 222, 195, 161], dtype=uint8)),
#  ('airplane', array([ 28,   0,  14, ..., 118,  79,  81], dtype=uint8)),
#  ('airplane', array([205, 169, 169, ..., 139, 134, 149], dtype=uint8)),
#  ('airplane', array([244, 240, 235, ...,  39,  59,  60], dtype=uint8)),
#  ('airplane', array([181, 189, 206, ..., 175, 172, 168], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ...,  95,  95,  95], dtype=uint8)),
#  ('airplane', array([181, 122,   0, ..., 235, 228, 231], dtype=uint8)),
#  ('airplane', array([163, 108,  77, ...,  92,  96,  85], dtype=uint8)),
#  ('airplane', array([189, 195, 176, ..., 148, 152, 146], dtype=uint8)),
#  ('airplane', array([240, 231, 221, ..., 108, 136, 136], dtype=uint8)),
#  ('airplane', array([242, 236, 255, ..., 253, 255, 254], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 241, 241, 241], dtype=uint8)),
#  ('airplane', array([229, 206,  97, ...,  94, 109, 135], dtype=uint8)),
#  ('airplane', array([135,  90,  57, ...,  93,  96,  64], dtype=uint8)),
#  ('airplane', array([169, 120,  82, ..., 141, 127, 131], dtype=uint8)),
#  ('airplane', array([188, 164, 146, ..., 191, 184, 169], dtype=uint8)),
#  ('airplane', array([215, 172, 151, ..., 237, 221, 214], dtype=uint8)),
#  ('airplane', array([254, 240, 244, ...,  29,  19,   2], dtype=uint8)),
#  ('airplane', array([92, 85, 68, ..., 71, 62, 49], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ...,  87,  97,  74], dtype=uint8)),
#  ('airplane', array([147, 101,  84, ..., 170, 159, 155], dtype=uint8)),
#  ('airplane', array([225, 200, 184, ..., 232, 191, 168], dtype=uint8)),
#  ('airplane', array([164, 173, 170, ..., 119, 165, 173], dtype=uint8)),
#  ('airplane', array([244, 182, 142, ..., 153, 126,  82], dtype=uint8)),
#  ('airplane', array([130,  86,  49, ..., 162, 135,  91], dtype=uint8)),
#  ('airplane', array([142, 214, 248, ...,   0,  14,  10], dtype=uint8)),
#  ('airplane', array([248, 239, 226, ...,  90,  96,  95], dtype=uint8)),
#  ('airplane', array([4, 0, 0, ..., 0, 0, 0], dtype=uint8)),
#  ('airplane', array([120,  96,  76, ..., 141,  91,  85], dtype=uint8)),
#  ('airplane', array([237, 226, 229, ...,  68, 127, 107], dtype=uint8)),
#  ('airplane', array([204, 199, 184, ..., 236, 212, 192], dtype=uint8)),
#  ('airplane', array([192, 171, 149, ..., 195, 180, 161], dtype=uint8)),
#  ('airplane', array([255, 255, 249, ..., 255, 255, 248], dtype=uint8)),
#  ('airplane', array([1, 1, 1, ..., 3, 3, 3], dtype=uint8)),
#  ('airplane', array([185, 120,  59, ..., 150, 130, 105], dtype=uint8)),
#  ('airplane', array([227, 194, 138, ..., 195, 178, 159], dtype=uint8)),
#  ('airplane', array([212, 237, 227, ..., 140, 136, 147], dtype=uint8)),
#  ('airplane', array([194, 154, 102, ..., 123,  99,  93], dtype=uint8)),
#  ('airplane', array([232, 159, 121, ..., 186, 174, 196], dtype=uint8)),
#  ('airplane', array([254, 255, 245, ..., 254, 254, 254], dtype=uint8)),
#  ('airplane', array([202, 142,  76, ..., 193, 209, 198], dtype=uint8)),
#  ('airplane', array([178, 120,  91, ..., 162, 127, 123], dtype=uint8)),
#  ('airplane', array([192, 184, 167, ...,  62, 131, 120], dtype=uint8)),
#  ('airplane', array([210, 158, 128, ..., 238, 175, 114], dtype=uint8)),
#  ('airplane', array([254, 254, 254, ..., 231, 231, 231], dtype=uint8)),
#  ('airplane', array([181, 172, 168, ..., 166, 148, 137], dtype=uint8)),
#  ('airplane', array([220, 206, 200, ..., 213, 195, 188], dtype=uint8)),
#  ...]

# %%
trainlabel=[]
trainpoint=[]
for i in traindata:
    trainlabel.append(i[0])
    trainpoint.append(i[1])

# %%
trainlabel
# Out:
# ['airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  ...]

# %%
trainlabel=np.array(trainlabel)

# %%
type(trainlabel)
# Out:
# numpy.ndarray

# %%
folder_name_list=["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

for name in folder_name_list:
    folder_path = './test/'+name
    list_name = name
    globals()[list_name] = []

    for filename in os.listdir(folder_path):
        # Check if the file is an image
        if filename.endswith('.jpg') or filename.endswith('.png'):
            # Read the image file
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            # Add the image to the list
            if img is not None:
                globals()[list_name].append((name,img.flatten()))

# %%
testdata= airplane+automobile+bird+cat+deer+dog+frog+horse+ship+truck

# %%
testdata
# Out:
# [('airplane', array([179, 159, 141, ...,  64,  72,  49], dtype=uint8)),
#  ('airplane', array([152, 123,  92, ..., 148, 118,  93], dtype=uint8)),
#  ('airplane', array([246, 251, 249, ..., 243, 248, 246], dtype=uint8)),
#  ('airplane', array([235, 246, 213, ...,  35,  56,  41], dtype=uint8)),
#  ('airplane', array([253, 131,  48, ...,  63, 121,  80], dtype=uint8)),
#  ('airplane', array([41, 69, 76, ..., 54, 84, 71], dtype=uint8)),
#  ('airplane', array([232, 235, 233, ...,  90, 123, 142], dtype=uint8)),
#  ('airplane', array([187, 149, 117, ..., 148, 140, 147], dtype=uint8)),
#  ('airplane', array([151, 137, 138, ..., 148, 136, 134], dtype=uint8)),
#  ('airplane', array([255, 255, 251, ..., 255, 255, 254], dtype=uint8)),
#  ('airplane', array([167, 143, 137, ...,  96,  99, 114], dtype=uint8)),
#  ('airplane', array([151, 115, 107, ..., 199, 176, 174], dtype=uint8)),
#  ('airplane', array([122, 171, 217, ..., 122,  97, 107], dtype=uint8)),
#  ('airplane', array([202, 202, 202, ..., 152, 152, 152], dtype=uint8)),
#  ('airplane', array([ 94,  65,  38, ..., 187, 153, 130], dtype=uint8)),
#  ('airplane', array([245, 221, 185, ...,  25,  46,  48], dtype=uint8)),
#  ('airplane', array([226, 205, 184, ..., 159, 177, 188], dtype=uint8)),
#  ('airplane', array([154, 160, 159, ..., 167, 169, 169], dtype=uint8)),
#  ('airplane', array([241, 214, 187, ..., 121, 103,  66], dtype=uint8)),
#  ('airplane', array([ 83,  84, 112, ..., 109,  80,  83], dtype=uint8)),
#  ('airplane', array([114,  74,  22, ...,  91,  45,  28], dtype=uint8)),
#  ('airplane', array([249, 247, 247, ..., 250, 255, 254], dtype=uint8)),
#  ('airplane', array([193, 107,  85, ..., 197, 137,  91], dtype=uint8)),
#  ('airplane', array([255, 255, 240, ...,  17,  20,  35], dtype=uint8)),
#  ('airplane', array([255, 194, 161, ..., 165,  93,  69], dtype=uint8)),
#  ('airplane', array([201, 189, 207, ..., 113, 125, 127], dtype=uint8)),
#  ('airplane', array([253, 253, 253, ...,  18,  34,  40], dtype=uint8)),
#  ('airplane', array([238, 243, 242, ...,  90,  95,  86], dtype=uint8)),
#  ('airplane', array([169, 183, 195, ..., 137, 156, 169], dtype=uint8)),
#  ('airplane', array([185, 192, 212, ..., 177, 198, 220], dtype=uint8)),
#  ('airplane', array([221, 186, 118, ..., 198, 207, 217], dtype=uint8)),
#  ('airplane', array([ 77, 125,  47, ..., 131, 158,  92], dtype=uint8)),
#  ('airplane', array([255, 253, 255, ..., 118, 113, 112], dtype=uint8)),
#  ('airplane', array([230, 197, 152, ..., 163, 147, 135], dtype=uint8)),
#  ('airplane', array([245, 229, 122, ..., 255, 246, 160], dtype=uint8)),
#  ('airplane', array([142, 116,  69, ..., 185, 140,  97], dtype=uint8)),
#  ('airplane', array([221, 227, 210, ..., 195, 204, 194], dtype=uint8)),
#  ('airplane', array([222, 206, 207, ..., 197, 193, 199], dtype=uint8)),
#  ('airplane', array([241, 218, 223, ..., 230, 194, 186], dtype=uint8)),
#  ('airplane', array([231, 206, 190, ...,  64,  52,  58], dtype=uint8)),
#  ('airplane', array([206, 220, 239, ...,  10,  25,  11], dtype=uint8)),
#  ('airplane', array([254, 245, 236, ..., 248, 250, 251], dtype=uint8)),
#  ('airplane', array([78, 91, 67, ..., 56, 82, 69], dtype=uint8)),
#  ('airplane', array([246, 248, 249, ..., 243, 240, 232], dtype=uint8)),
#  ('airplane', array([165, 131, 107, ...,  13,  69,  56], dtype=uint8)),
#  ('airplane', array([201,  96,  75, ..., 219, 183, 129], dtype=uint8)),
#  ('airplane', array([210, 205, 206, ..., 218, 211, 218], dtype=uint8)),
#  ('airplane', array([194, 194, 194, ..., 112, 112, 112], dtype=uint8)),
#  ('airplane', array([81, 72, 69, ..., 58, 50, 51], dtype=uint8)),
#  ('airplane', array([198, 197, 183, ...,  84, 133, 113], dtype=uint8)),
#  ('airplane', array([243, 198, 155, ..., 252, 203, 171], dtype=uint8)),
#  ('airplane', array([ 93, 121,  78, ...,  95, 110,  82], dtype=uint8)),
#  ('airplane', array([186, 164, 128, ...,  58, 101,  86], dtype=uint8)),
#  ('airplane', array([202, 196, 185, ..., 177, 150, 113], dtype=uint8)),
#  ('airplane', array([197, 204, 197, ...,  98, 129, 152], dtype=uint8)),
#  ('airplane', array([ 97, 148, 144, ..., 113, 136, 144], dtype=uint8)),
#  ('airplane', array([185, 190, 181, ..., 199, 212, 210], dtype=uint8)),
#  ('airplane', array([226, 223, 219, ..., 162, 166, 160], dtype=uint8)),
#  ('airplane', array([230, 220, 226, ..., 218, 229, 226], dtype=uint8)),
#  ('airplane', array([118, 120, 131, ..., 139, 141, 151], dtype=uint8)),
#  ('airplane', array([180, 160, 105, ..., 179, 147, 112], dtype=uint8)),
#  ('airplane', array([253, 255, 255, ...,  52,  61,  64], dtype=uint8)),
#  ('airplane', array([218, 216, 185, ..., 128, 123, 120], dtype=uint8)),
#  ('airplane', array([191, 171, 154, ..., 189, 169, 128], dtype=uint8)),
#  ('airplane', array([227, 239, 243, ...,  93, 144, 160], dtype=uint8)),
#  ('airplane', array([49, 19,  0, ..., 92, 36, 41], dtype=uint8)),
#  ('airplane', array([212, 185, 175, ..., 200, 172, 165], dtype=uint8)),
#  ('airplane', array([252, 246, 241, ..., 164, 155, 158], dtype=uint8)),
#  ('airplane', array([217, 229, 233, ...,  83,  85,  86], dtype=uint8)),
#  ('airplane', array([211, 145,  97, ...,  57,  96,  64], dtype=uint8)),
#  ('airplane', array([160, 123, 103, ..., 188, 167, 182], dtype=uint8)),
#  ('airplane', array([245, 234, 255, ..., 227, 255, 255], dtype=uint8)),
#  ('airplane', array([173, 171, 183, ..., 119, 125, 124], dtype=uint8)),
#  ('airplane', array([161,  69,   0, ..., 173, 161, 181], dtype=uint8)),
#  ('airplane', array([206, 212, 207, ..., 164, 177, 191], dtype=uint8)),
#  ('airplane', array([211, 187, 145, ...,  51,  50,  36], dtype=uint8)),
#  ('airplane', array([209, 154, 145, ..., 220, 185, 175], dtype=uint8)),
#  ('airplane', array([ 91, 123, 146, ...,  81, 112, 135], dtype=uint8)),
#  ('airplane', array([191, 118,  74, ..., 129, 138, 141], dtype=uint8)),
#  ('airplane', array([247, 252, 251, ..., 173, 190, 209], dtype=uint8)),
#  ('airplane', array([136, 133, 135, ...,  68,  71,  76], dtype=uint8)),
#  ('airplane', array([187, 187, 187, ...,  63,  63,  63], dtype=uint8)),
#  ('airplane', array([130,  81,  67, ...,  68,  65,  60], dtype=uint8)),
#  ('airplane', array([237, 194, 143, ..., 137, 155, 154], dtype=uint8)),
#  ('airplane', array([237, 220, 164, ..., 250, 226, 202], dtype=uint8)),
#  ('airplane', array([158, 149, 145, ..., 151, 142, 138], dtype=uint8)),
#  ('airplane', array([189, 140,  90, ..., 199, 194, 195], dtype=uint8)),
#  ('airplane', array([178, 157, 126, ..., 104, 120, 132], dtype=uint8)),
#  ('airplane', array([244, 244, 244, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([215, 195, 178, ..., 206, 182, 146], dtype=uint8)),
#  ('airplane', array([221, 158,  78, ..., 161, 169, 158], dtype=uint8)),
#  ('airplane', array([9, 5, 4, ..., 0, 0, 6], dtype=uint8)),
#  ('airplane', array([180, 192, 192, ..., 216, 217, 208], dtype=uint8)),
#  ('airplane', array([  5,  91, 187, ...,  22,  46,  64], dtype=uint8)),
#  ('airplane', array([108, 131, 127, ...,  69, 114, 135], dtype=uint8)),
#  ('airplane', array([191, 195, 224, ..., 142, 151, 178], dtype=uint8)),
#  ('airplane', array([223, 200, 174, ..., 187, 174, 160], dtype=uint8)),
#  ('airplane', array([146, 135, 115, ...,  82,  92,  92], dtype=uint8)),
#  ('airplane', array([201, 157, 128, ..., 250, 212, 188], dtype=uint8)),
#  ('airplane', array([152, 117, 103, ..., 173, 122,  72], dtype=uint8)),
#  ('airplane', array([218, 213, 204, ...,  53, 106,  86], dtype=uint8)),
#  ('airplane', array([112, 109, 101, ...,  47, 104,  95], dtype=uint8)),
#  ('airplane', array([162, 163, 159, ..., 167, 165, 154], dtype=uint8)),
#  ('airplane', array([46, 46, 32, ..., 41, 53, 41], dtype=uint8)),
#  ('airplane', array([187, 144,  77, ..., 207, 173, 119], dtype=uint8)),
#  ('airplane', array([151, 115,  55, ..., 178, 134,  75], dtype=uint8)),
#  ('airplane', array([209, 209, 209, ..., 208, 208, 208], dtype=uint8)),
#  ('airplane', array([188, 143, 106, ..., 197, 177, 160], dtype=uint8)),
#  ('airplane', array([ 70, 141, 168, ...,  53, 111, 133], dtype=uint8)),
#  ('airplane', array([205, 207, 201, ..., 133, 182, 214], dtype=uint8)),
#  ('airplane', array([ 57, 100,  97, ...,  53,  69,  51], dtype=uint8)),
#  ('airplane', array([76, 54,  2, ..., 68, 53,  7], dtype=uint8)),
#  ('airplane', array([211, 174, 146, ..., 126, 102,  84], dtype=uint8)),
#  ('airplane', array([106, 102,  97, ..., 115, 127, 133], dtype=uint8)),
#  ('airplane', array([204, 157, 149, ..., 255, 255, 252], dtype=uint8)),
#  ('airplane', array([189, 171, 172, ..., 187, 128, 118], dtype=uint8)),
#  ('airplane', array([255, 254, 255, ..., 252, 251, 247], dtype=uint8)),
#  ('airplane', array([198, 196, 178, ...,  45,  86, 101], dtype=uint8)),
#  ('airplane', array([155, 166, 134, ..., 148, 146, 115], dtype=uint8)),
#  ('airplane', array([230, 193, 189, ..., 136,  89,  62], dtype=uint8)),
#  ('airplane', array([161, 172, 170, ..., 173, 144, 130], dtype=uint8)),
#  ('airplane', array([ 45,  28,  41, ...,  81, 120, 188], dtype=uint8)),
#  ('airplane', array([126, 116, 106, ...,  43,  44,  70], dtype=uint8)),
#  ('airplane', array([154, 154, 154, ...,  65,  65,  65], dtype=uint8)),
#  ('airplane', array([ 77,  36,   0, ..., 123, 104,  53], dtype=uint8)),
#  ('airplane', array([252, 254, 242, ..., 255, 254, 247], dtype=uint8)),
#  ('airplane', array([129,  74,  37, ..., 119,  74,  40], dtype=uint8)),
#  ('airplane', array([118, 140, 128, ...,  99, 138, 176], dtype=uint8)),
#  ('airplane', array([246, 246, 240, ..., 175, 192, 219], dtype=uint8)),
#  ('airplane', array([83, 62, 47, ..., 90, 57, 31], dtype=uint8)),
#  ('airplane', array([130, 127, 122, ..., 127, 121, 126], dtype=uint8)),
#  ('airplane', array([214, 152, 111, ..., 189, 151, 119], dtype=uint8)),
#  ('airplane', array([204, 164, 139, ..., 234, 237, 245], dtype=uint8)),
#  ('airplane', array([234, 215, 212, ..., 137,  82,  51], dtype=uint8)),
#  ('airplane', array([184, 135, 113, ..., 156, 113,  96], dtype=uint8)),
#  ('airplane', array([93, 81, 53, ..., 98, 81, 54], dtype=uint8)),
#  ('airplane', array([239, 241, 241, ..., 240, 240, 240], dtype=uint8)),
#  ('airplane', array([219, 175, 128, ...,  54,  66,  72], dtype=uint8)),
#  ('airplane', array([202, 169, 123, ...,  92, 109, 100], dtype=uint8)),
#  ('airplane', array([205, 177, 147, ..., 105,  98,  83], dtype=uint8)),
#  ('airplane', array([208, 174, 151, ..., 227, 177, 155], dtype=uint8)),
#  ('airplane', array([222, 167, 122, ..., 248, 179, 139], dtype=uint8)),
#  ('airplane', array([142, 164, 176, ..., 181, 202, 210], dtype=uint8)),
#  ('airplane', array([187, 196, 200, ..., 139, 141, 141], dtype=uint8)),
#  ('airplane', array([157, 102,  89, ..., 146, 106,  94], dtype=uint8)),
#  ('airplane', array([191, 180, 182, ..., 182, 172, 184], dtype=uint8)),
#  ('airplane', array([208, 141,  54, ..., 136, 142, 177], dtype=uint8)),
#  ('airplane', array([184, 144, 125, ...,  77,  79,  80], dtype=uint8)),
#  ('airplane', array([233, 174,  71, ..., 215, 180, 107], dtype=uint8)),
#  ('airplane', array([210, 195, 193, ...,  53,  98,  95], dtype=uint8)),
#  ('airplane', array([189, 162, 105, ..., 184, 156, 121], dtype=uint8)),
#  ('airplane', array([161, 143, 144, ...,  73,  91, 108], dtype=uint8)),
#  ('airplane', array([154, 138, 125, ..., 130, 149, 154], dtype=uint8)),
#  ('airplane', array([240, 235, 236, ..., 105, 118, 134], dtype=uint8)),
#  ('airplane', array([203, 133, 103, ..., 198, 115,  83], dtype=uint8)),
#  ('airplane', array([30, 51, 43, ..., 19, 36, 23], dtype=uint8)),
#  ('airplane', array([229, 219, 231, ..., 255, 246, 210], dtype=uint8)),
#  ('airplane', array([244, 244, 238, ..., 254, 249, 246], dtype=uint8)),
#  ('airplane', array([230, 155, 103, ..., 236, 152, 104], dtype=uint8)),
#  ('airplane', array([129,  98,  77, ...,  51,  42,  69], dtype=uint8)),
#  ('airplane', array([250, 250, 250, ..., 238, 246, 245], dtype=uint8)),
#  ('airplane', array([206, 178, 143, ..., 203, 206, 211], dtype=uint8)),
#  ('airplane', array([240, 235, 234, ..., 241, 236, 237], dtype=uint8)),
#  ('airplane', array([ 60, 109, 107, ...,  91, 116, 132], dtype=uint8)),
#  ('airplane', array([122,  77,  33, ..., 124,  72,   0], dtype=uint8)),
#  ('airplane', array([148,  85,  57, ..., 209, 170, 131], dtype=uint8)),
#  ('airplane', array([115,  99,  56, ...,  27,  30,  38], dtype=uint8)),
#  ('airplane', array([171, 133,  98, ..., 174, 175, 185], dtype=uint8)),
#  ('airplane', array([190, 195, 198, ...,  22,  78,  59], dtype=uint8)),
#  ('airplane', array([149, 114,  80, ..., 184, 168, 151], dtype=uint8)),
#  ('airplane', array([138,  56,  69, ..., 130,  96, 136], dtype=uint8)),
#  ('airplane', array([153, 140,  96, ..., 158, 162, 120], dtype=uint8)),
#  ('airplane', array([154, 162, 101, ..., 249, 255, 254], dtype=uint8)),
#  ('airplane', array([249, 249, 249, ..., 233, 233, 233], dtype=uint8)),
#  ('airplane', array([244, 207, 179, ..., 244, 190, 157], dtype=uint8)),
#  ('airplane', array([173, 151, 139, ...,  62,  96,  66], dtype=uint8)),
#  ('airplane', array([241, 181, 127, ..., 226, 172, 111], dtype=uint8)),
#  ('airplane', array([198, 151, 119, ..., 219, 181, 146], dtype=uint8)),
#  ('airplane', array([223, 216, 207, ..., 133, 126, 107], dtype=uint8)),
#  ('airplane', array([146, 110,  50, ..., 110,  83,  56], dtype=uint8)),
#  ('airplane', array([165,  92,  30, ..., 181,  92,  48], dtype=uint8)),
#  ('airplane', array([186, 201, 217, ..., 217, 242, 255], dtype=uint8)),
#  ('airplane', array([ 39,  51,  57, ..., 186, 152, 129], dtype=uint8)),
#  ('airplane', array([243, 203, 168, ..., 255, 233, 217], dtype=uint8)),
#  ('airplane', array([251, 168, 113, ..., 248, 167, 116], dtype=uint8)),
#  ('airplane', array([152, 150, 119, ...,  49,  66,  52], dtype=uint8)),
#  ('airplane', array([125, 134, 144, ..., 101, 120, 127], dtype=uint8)),
#  ('airplane', array([201, 201, 201, ..., 162, 162, 162], dtype=uint8)),
#  ('airplane', array([225, 197, 120, ...,  63,  52,  60], dtype=uint8)),
#  ('airplane', array([234, 196, 164, ..., 255, 235, 203], dtype=uint8)),
#  ('airplane', array([164, 121, 112, ..., 105,  98, 101], dtype=uint8)),
#  ('airplane', array([123,  73,  45, ..., 148, 160, 170], dtype=uint8)),
#  ('airplane', array([240, 162,  79, ..., 216, 162,  99], dtype=uint8)),
#  ('airplane', array([112,  89,  74, ..., 111,  57,   0], dtype=uint8)),
#  ('airplane', array([238, 223, 197, ..., 151, 163, 151], dtype=uint8)),
#  ('airplane', array([228, 159, 132, ..., 219, 162, 137], dtype=uint8)),
#  ('airplane', array([116,  48,  41, ...,  29,  16,  14], dtype=uint8)),
#  ('airplane', array([213, 194, 167, ..., 200, 191, 177], dtype=uint8)),
#  ('airplane', array([194, 183, 186, ...,  78,  37,  15], dtype=uint8)),
#  ('airplane', array([54, 59, 44, ..., 96, 89, 94], dtype=uint8)),
#  ('airplane', array([188, 152, 142, ..., 183, 155, 144], dtype=uint8)),
#  ('airplane', array([145, 194, 196, ..., 128, 178, 196], dtype=uint8)),
#  ('airplane', array([206, 199, 202, ..., 237, 235, 225], dtype=uint8)),
#  ('airplane', array([ 6, 17,  7, ..., 50, 40, 30], dtype=uint8)),
#  ('airplane', array([157, 154, 140, ..., 135, 133, 132], dtype=uint8)),
#  ('airplane', array([22,  9, 11, ..., 39, 25,  7], dtype=uint8)),
#  ('airplane', array([226, 189, 161, ..., 143, 153, 177], dtype=uint8)),
#  ('airplane', array([175, 154, 122, ..., 118, 126, 125], dtype=uint8)),
#  ('airplane', array([103, 125, 123, ...,  78,  93, 109], dtype=uint8)),
#  ('airplane', array([152, 146, 135, ..., 109, 111, 105], dtype=uint8)),
#  ('airplane', array([231, 215, 192, ..., 255, 252, 255], dtype=uint8)),
#  ('airplane', array([187, 161, 107, ..., 179, 159, 102], dtype=uint8)),
#  ('airplane', array([246, 244, 236, ..., 235, 244, 241], dtype=uint8)),
#  ('airplane', array([248, 248, 248, ..., 118, 118, 118], dtype=uint8)),
#  ('airplane', array([190, 162, 127, ...,  71,  84,  82], dtype=uint8)),
#  ('airplane', array([ 74, 180, 143, ...,  66, 169, 131], dtype=uint8)),
#  ('airplane', array([244, 130, 107, ...,  52,  87,  97], dtype=uint8)),
#  ('airplane', array([151, 157, 156, ..., 178, 186, 175], dtype=uint8)),
#  ('airplane', array([155, 108,  40, ..., 149, 101,  77], dtype=uint8)),
#  ('airplane', array([145, 153, 143, ...,  47,  62,  64], dtype=uint8)),
#  ('airplane', array([174, 200, 214, ..., 112, 128, 141], dtype=uint8)),
#  ('airplane', array([147,  80,  23, ..., 195, 169, 145], dtype=uint8)),
#  ('airplane', array([164, 156, 143, ..., 208, 185, 193], dtype=uint8)),
#  ('airplane', array([172, 167, 142, ...,  89, 116, 126], dtype=uint8)),
#  ('airplane', array([209, 209, 209, ..., 254, 254, 254], dtype=uint8)),
#  ('airplane', array([68, 55, 63, ..., 45, 52, 55], dtype=uint8)),
#  ('airplane', array([163, 155, 138, ...,  34,  97,  88], dtype=uint8)),
#  ('airplane', array([221, 199, 193, ..., 132, 155, 140], dtype=uint8)),
#  ('airplane', array([150, 193, 202, ..., 249, 249, 255], dtype=uint8)),
#  ('airplane', array([227, 214, 138, ..., 209, 200, 120], dtype=uint8)),
#  ('airplane', array([193, 183, 195, ...,  94,  92,  92], dtype=uint8)),
#  ('airplane', array([178, 154, 124, ...,  74,  95,  80], dtype=uint8)),
#  ('airplane', array([ 78,  51,  14, ..., 118,  62,   0], dtype=uint8)),
#  ('airplane', array([133, 133, 133, ..., 234, 234, 234], dtype=uint8)),
#  ('airplane', array([237, 235, 235, ..., 209, 201, 194], dtype=uint8)),
#  ('airplane', array([134, 131, 123, ...,  30,  77,  55], dtype=uint8)),
#  ('airplane', array([245, 237, 237, ..., 253, 251, 250], dtype=uint8)),
#  ('airplane', array([210, 200, 170, ...,  88,  97,  94], dtype=uint8)),
#  ('airplane', array([ 41,  41,  41, ..., 163, 163, 163], dtype=uint8)),
#  ('airplane', array([119,  45,  33, ..., 186, 103,  58], dtype=uint8)),
#  ('airplane', array([253, 253, 253, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([197, 209, 191, ...,  90, 131, 110], dtype=uint8)),
#  ('airplane', array([124, 123, 109, ...,  48,  62,  50], dtype=uint8)),
#  ('airplane', array([197, 160, 122, ..., 136, 145, 149], dtype=uint8)),
#  ('airplane', array([247, 176, 126, ..., 161, 157, 152], dtype=uint8)),
#  ('airplane', array([194, 150, 121, ..., 212, 179, 163], dtype=uint8)),
#  ('airplane', array([255, 250, 255, ..., 255, 245, 253], dtype=uint8)),
#  ('airplane', array([228, 162, 114, ..., 222, 173, 125], dtype=uint8)),
#  ('airplane', array([211, 214, 198, ...,   7, 113,  76], dtype=uint8)),
#  ('airplane', array([ 74,  33,  10, ..., 133, 149, 178], dtype=uint8)),
#  ('airplane', array([148, 143, 144, ..., 160, 152, 153], dtype=uint8)),
#  ('airplane', array([ 73,  62,  58, ..., 181, 170, 178], dtype=uint8)),
#  ('airplane', array([164, 193, 202, ..., 106, 127,  95], dtype=uint8)),
#  ('airplane', array([120, 114,  67, ...,  99, 144, 117], dtype=uint8)),
#  ('airplane', array([201, 140, 114, ..., 174, 154, 153], dtype=uint8)),
#  ('airplane', array([145, 152, 171, ..., 201, 227, 241], dtype=uint8)),
#  ('airplane', array([214, 217, 195, ..., 137, 206, 246], dtype=uint8)),
#  ('airplane', array([108,  88,  70, ..., 105,  83,  71], dtype=uint8)),
#  ('airplane', array([255, 234, 118, ...,  96, 150, 181], dtype=uint8)),
#  ('airplane', array([198, 205, 202, ...,  47, 116, 106], dtype=uint8)),
#  ('airplane', array([203, 172, 141, ..., 197, 156, 124], dtype=uint8)),
#  ('airplane', array([193, 156, 148, ..., 186, 152, 153], dtype=uint8)),
#  ('airplane', array([222, 223, 203, ...,  96,  88,  71], dtype=uint8)),
#  ('airplane', array([178, 166, 160, ..., 155, 149, 144], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([249, 209, 180, ..., 148,  97,  65], dtype=uint8)),
#  ('airplane', array([251, 251, 255, ..., 138, 158, 205], dtype=uint8)),
#  ('airplane', array([244, 255, 255, ..., 255, 255, 249], dtype=uint8)),
#  ('airplane', array([102,  38,   3, ..., 176, 126, 103], dtype=uint8)),
#  ('airplane', array([140, 146, 157, ..., 137, 123, 117], dtype=uint8)),
#  ('airplane', array([222, 213, 199, ...,  43,  51,  40], dtype=uint8)),
#  ('airplane', array([163, 137, 130, ...,  27,  30,  44], dtype=uint8)),
#  ('airplane', array([254, 212, 169, ...,  60, 126, 101], dtype=uint8)),
#  ('airplane', array([170, 163, 138, ..., 170, 184, 178], dtype=uint8)),
#  ('airplane', array([152, 132, 127, ..., 149, 123, 116], dtype=uint8)),
#  ('airplane', array([190, 182, 192, ..., 100,  76,  84], dtype=uint8)),
#  ('airplane', array([ 35,  69,  99, ...,  18,  72, 102], dtype=uint8)),
#  ('airplane', array([255, 239, 255, ..., 176, 161, 182], dtype=uint8)),
#  ('airplane', array([253, 239, 197, ..., 251, 254, 255], dtype=uint8)),
#  ('airplane', array([255, 255, 251, ..., 248, 255, 244], dtype=uint8)),
#  ('airplane', array([209, 190, 183, ...,  63,  73,  57], dtype=uint8)),
#  ('airplane', array([134, 100,  87, ..., 122, 101,  99], dtype=uint8)),
#  ('airplane', array([122, 118, 117, ..., 106, 124, 123], dtype=uint8)),
#  ('airplane', array([208, 237, 242, ...,  52,  75,  90], dtype=uint8)),
#  ('airplane', array([214, 179, 166, ..., 102,  57,   0], dtype=uint8)),
#  ('airplane', array([159, 148, 140, ..., 198, 203, 204], dtype=uint8)),
#  ('airplane', array([231, 233, 233, ..., 248, 244, 243], dtype=uint8)),
#  ('airplane', array([203, 155, 137, ..., 208, 149, 103], dtype=uint8)),
#  ('airplane', array([145, 137, 107, ..., 120, 114,  77], dtype=uint8)),
#  ('airplane', array([184, 133,  83, ..., 222, 230, 223], dtype=uint8)),
#  ('airplane', array([158, 158, 146, ..., 129, 129, 111], dtype=uint8)),
#  ('airplane', array([183, 172, 140, ...,  75,  75,  57], dtype=uint8)),
#  ('airplane', array([220, 196,  96, ..., 128,  98,   9], dtype=uint8)),
#  ('airplane', array([199, 211, 223, ...,  72,  84,  84], dtype=uint8)),
#  ('airplane', array([193, 103,  39, ..., 222, 128,  62], dtype=uint8)),
#  ('airplane', array([178, 145, 125, ..., 115, 126, 148], dtype=uint8)),
#  ('airplane', array([227, 212, 193, ..., 161, 180, 193], dtype=uint8)),
#  ('airplane', array([133,  83,  47, ..., 130,  92,  60], dtype=uint8)),
#  ('airplane', array([175, 142, 103, ..., 151, 174, 220], dtype=uint8)),
#  ('airplane', array([167, 115,  79, ..., 136, 170, 164], dtype=uint8)),
#  ('airplane', array([228, 169, 120, ..., 226, 177, 127], dtype=uint8)),
#  ('airplane', array([213, 169, 116, ..., 225, 188, 120], dtype=uint8)),
#  ('airplane', array([210, 222, 204, ..., 225, 224, 210], dtype=uint8)),
#  ('airplane', array([169,  95,  71, ..., 158, 120,  72], dtype=uint8)),
#  ('airplane', array([229, 188, 245, ..., 220, 203, 236], dtype=uint8)),
#  ('airplane', array([255, 243, 241, ..., 113, 115,  96], dtype=uint8)),
#  ('airplane', array([194, 201, 196, ...,  18,  44,  60], dtype=uint8)),
#  ('airplane', array([155, 120,  94, ..., 162, 143, 128], dtype=uint8)),
#  ('airplane', array([177, 107,  84, ..., 176, 167, 100], dtype=uint8)),
#  ('airplane', array([194, 163, 154, ...,  72,  77,  98], dtype=uint8)),
#  ('airplane', array([199, 196, 191, ..., 222, 232, 242], dtype=uint8)),
#  ('airplane', array([250, 250, 250, ..., 251, 253, 254], dtype=uint8)),
#  ('airplane', array([161, 149, 143, ...,  92,  78,  72], dtype=uint8)),
#  ('airplane', array([197, 159, 147, ..., 106,  49,  10], dtype=uint8)),
#  ('airplane', array([104, 117, 131, ...,  60, 100, 135], dtype=uint8)),
#  ('airplane', array([2, 1, 0, ..., 8, 0, 1], dtype=uint8)),
#  ('airplane', array([240, 179, 135, ..., 244, 186, 150], dtype=uint8)),
#  ('airplane', array([202, 191, 177, ..., 198, 193, 184], dtype=uint8)),
#  ('airplane', array([84, 90, 37, ..., 90, 81, 68], dtype=uint8)),
#  ('airplane', array([147, 174, 218, ..., 133, 187, 210], dtype=uint8)),
#  ('airplane', array([219, 169, 149, ..., 150, 110, 105], dtype=uint8)),
#  ('airplane', array([ 34,  72, 104, ...,  94, 143, 169], dtype=uint8)),
#  ('airplane', array([193, 146, 114, ..., 197, 154, 127], dtype=uint8)),
#  ('airplane', array([ 67,  73,  86, ..., 139, 137, 126], dtype=uint8)),
#  ('airplane', array([190, 158,  83, ..., 150, 174, 180], dtype=uint8)),
#  ('airplane', array([196, 146,  46, ..., 202, 157,  52], dtype=uint8)),
#  ('airplane', array([247, 230, 217, ..., 230, 223, 204], dtype=uint8)),
#  ('airplane', array([96, 84, 56, ..., 52, 79, 76], dtype=uint8)),
#  ('airplane', array([255, 255, 249, ..., 128, 115, 107], dtype=uint8)),
#  ('airplane', array([152, 157, 148, ..., 149, 171, 159], dtype=uint8)),
#  ('airplane', array([115,  94,  96, ...,  95, 109, 121], dtype=uint8)),
#  ('airplane', array([241, 231, 231, ..., 171, 167, 173], dtype=uint8)),
#  ('airplane', array([198, 189, 186, ...,  76,  90, 118], dtype=uint8)),
#  ('airplane', array([179, 182, 166, ..., 170, 159, 132], dtype=uint8)),
#  ('airplane', array([225, 213, 209, ..., 180, 162, 133], dtype=uint8)),
#  ('airplane', array([223, 202, 180, ..., 159, 182, 208], dtype=uint8)),
#  ('airplane', array([114, 120, 143, ...,  42,  53,  80], dtype=uint8)),
#  ('airplane', array([198, 148, 130, ...,  69, 150, 135], dtype=uint8)),
#  ('airplane', array([242, 234, 241, ...,  77, 114, 112], dtype=uint8)),
#  ('airplane', array([223, 219, 218, ..., 206, 217, 207], dtype=uint8)),
#  ('airplane', array([194, 159, 125, ..., 199, 167, 148], dtype=uint8)),
#  ('airplane', array([247, 242, 217, ..., 113, 149, 165], dtype=uint8)),
#  ('airplane', array([247, 247, 247, ..., 249, 249, 249], dtype=uint8)),
#  ('airplane', array([66, 59, 62, ..., 53, 52, 56], dtype=uint8)),
#  ('airplane', array([255, 254, 255, ..., 186, 197, 217], dtype=uint8)),
#  ('airplane', array([ 95,  95,  95, ..., 145, 145, 145], dtype=uint8)),
#  ('airplane', array([220, 192, 168, ..., 224, 207, 186], dtype=uint8)),
#  ('airplane', array([239, 239, 227, ..., 173, 164, 137], dtype=uint8)),
#  ('airplane', array([163, 166, 197, ..., 135, 120, 141], dtype=uint8)),
#  ('airplane', array([149, 138, 140, ..., 251, 255, 254], dtype=uint8)),
#  ('airplane', array([ 34, 117, 118, ...,  71,  82,  72], dtype=uint8)),
#  ('airplane', array([146,  99, 107, ..., 170, 132, 108], dtype=uint8)),
#  ('airplane', array([255, 235, 209, ...,  42,  41,  45], dtype=uint8)),
#  ('airplane', array([249, 249, 249, ..., 219, 219, 219], dtype=uint8)),
#  ('airplane', array([208, 187, 172, ..., 134, 129, 130], dtype=uint8)),
#  ('airplane', array([107, 121, 115, ...,  78, 118, 160], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 248, 255, 255], dtype=uint8)),
#  ('airplane', array([200, 184, 167, ...,  59,  65,  72], dtype=uint8)),
#  ('airplane', array([103,  52,  42, ...,  50,  49,  45], dtype=uint8)),
#  ('airplane', array([153, 139, 133, ...,  56,  74, 115], dtype=uint8)),
#  ('airplane', array([100,  38,  20, ..., 101,  86, 113], dtype=uint8)),
#  ('airplane', array([173, 194, 196, ..., 184, 188, 183], dtype=uint8)),
#  ('airplane', array([ 96, 131,  57, ...,  49,  43,  32], dtype=uint8)),
#  ('airplane', array([255, 101,  78, ..., 255, 176, 161], dtype=uint8)),
#  ('airplane', array([201, 109,  62, ..., 163, 190, 210], dtype=uint8)),
#  ('airplane', array([223, 186, 178, ..., 100,  96, 101], dtype=uint8)),
#  ('airplane', array([225, 218,  85, ..., 214, 127,   0], dtype=uint8)),
#  ('airplane', array([221, 181, 153, ..., 149, 108,  83], dtype=uint8)),
#  ('airplane', array([ 52,  66,  65, ..., 137, 145, 138], dtype=uint8)),
#  ('airplane', array([255, 230, 194, ..., 251, 230, 198], dtype=uint8)),
#  ('airplane', array([114,  86,  69, ...,  92,  56,  50], dtype=uint8)),
#  ('airplane', array([158, 136, 130, ...,  64,  79,  98], dtype=uint8)),
#  ('airplane', array([205, 225, 230, ..., 219, 212, 225], dtype=uint8)),
#  ('airplane', array([250, 248, 248, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([254, 231, 199, ..., 208, 217, 220], dtype=uint8)),
#  ('airplane', array([168, 140, 106, ..., 171, 145, 109], dtype=uint8)),
#  ('airplane', array([254, 254, 254, ..., 255, 254, 254], dtype=uint8)),
#  ('airplane', array([124,  56,  43, ..., 215, 163, 157], dtype=uint8)),
#  ('airplane', array([125,  68,  36, ..., 126,  69,  44], dtype=uint8)),
#  ('airplane', array([216, 177, 149, ..., 119, 128, 132], dtype=uint8)),
#  ('airplane', array([183, 155, 131, ..., 202, 173, 158], dtype=uint8)),
#  ('airplane', array([209, 162, 106, ..., 104, 148, 135], dtype=uint8)),
#  ('airplane', array([215, 215, 215, ..., 105, 105, 105], dtype=uint8)),
#  ('airplane', array([205, 206, 204, ..., 226, 232, 227], dtype=uint8)),
#  ('airplane', array([169, 160, 150, ..., 108, 127, 124], dtype=uint8)),
#  ('airplane', array([210, 205, 202, ..., 110, 129, 137], dtype=uint8)),
#  ('airplane', array([174, 150, 144, ..., 189, 187, 169], dtype=uint8)),
#  ('airplane', array([141, 136, 135, ...,   8,  74,  63], dtype=uint8)),
#  ('airplane', array([253, 255, 255, ...,  60, 152, 133], dtype=uint8)),
#  ('airplane', array([108, 112, 106, ..., 155, 165, 152], dtype=uint8)),
#  ('airplane', array([220, 182, 140, ..., 158,  99,  54], dtype=uint8)),
#  ('airplane', array([113,  82,  51, ..., 178, 177, 173], dtype=uint8)),
#  ('airplane', array([251, 255, 247, ...,  59,  47,  41], dtype=uint8)),
#  ('airplane', array([156,  68,  27, ...,  34,  29,  30], dtype=uint8)),
#  ('airplane', array([ 84,  64,  29, ..., 167, 158, 161], dtype=uint8)),
#  ('airplane', array([161,  93,  10, ...,  64,  78,  72], dtype=uint8)),
#  ('airplane', array([252, 226, 160, ..., 123, 136, 150], dtype=uint8)),
#  ('airplane', array([ 96, 118,  99, ...,  85, 114, 123], dtype=uint8)),
#  ('airplane', array([196, 197, 201, ..., 124, 116, 146], dtype=uint8)),
#  ('airplane', array([176, 119, 122, ..., 143,  80,  89], dtype=uint8)),
#  ('airplane', array([231, 227, 222, ..., 225, 224, 220], dtype=uint8)),
#  ('airplane', array([241, 238, 255, ..., 255, 244, 255], dtype=uint8)),
#  ('airplane', array([151, 160, 164, ..., 197, 205, 205], dtype=uint8)),
#  ('airplane', array([177, 117,  21, ..., 215, 213, 159], dtype=uint8)),
#  ('airplane', array([106,  73,  54, ..., 118,  92,  78], dtype=uint8)),
#  ('airplane', array([106, 145, 183, ..., 136, 167, 188], dtype=uint8)),
#  ('airplane', array([182, 169, 143, ..., 150, 153, 157], dtype=uint8)),
#  ('airplane', array([177, 171, 158, ..., 162, 145, 124], dtype=uint8)),
#  ('airplane', array([251, 254, 255, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([153,  94,  75, ..., 184, 152, 129], dtype=uint8)),
#  ('airplane', array([164, 157, 148, ..., 119, 120, 116], dtype=uint8)),
#  ('airplane', array([215, 169, 135, ..., 172, 153, 116], dtype=uint8)),
#  ('airplane', array([169, 189, 200, ..., 182, 191, 225], dtype=uint8)),
#  ('airplane', array([141, 140, 130, ..., 147, 149, 150], dtype=uint8)),
#  ('airplane', array([138, 140, 140, ..., 212, 216, 217], dtype=uint8)),
#  ('airplane', array([218, 155, 151, ..., 239, 214, 172], dtype=uint8)),
#  ('airplane', array([199, 171, 130, ..., 110, 106,  77], dtype=uint8)),
#  ('airplane', array([ 74, 102,  83, ...,  85,  97, 115], dtype=uint8)),
#  ('airplane', array([135, 121,  62, ...,  29,  52,  60], dtype=uint8)),
#  ('airplane', array([193, 202, 216, ..., 196, 212, 229], dtype=uint8)),
#  ('airplane', array([ 95, 187, 252, ..., 161, 208, 230], dtype=uint8)),
#  ('airplane', array([131, 144, 158, ..., 140, 153, 167], dtype=uint8)),
#  ('airplane', array([163,  86,  23, ..., 154,  83,  50], dtype=uint8)),
#  ('airplane', array([222, 233, 237, ..., 202, 214, 224], dtype=uint8)),
#  ('airplane', array([164, 164, 164, ..., 228, 228, 228], dtype=uint8)),
#  ('airplane', array([ 92,  98, 109, ..., 157, 166, 169], dtype=uint8)),
#  ('airplane', array([233, 197, 173, ...,  70, 126, 103], dtype=uint8)),
#  ('airplane', array([156,  82,  18, ..., 132, 132, 138], dtype=uint8)),
#  ('airplane', array([124,  77,  45, ...,  86,  67,  46], dtype=uint8)),
#  ('airplane', array([ 3, 10,  7, ...,  4,  0,  0], dtype=uint8)),
#  ('airplane', array([163,  82,  55, ..., 172, 103,  86], dtype=uint8)),
#  ('airplane', array([ 45,  73, 174, ..., 118, 186, 255], dtype=uint8)),
#  ('airplane', array([255, 150, 119, ..., 239, 142,  92], dtype=uint8)),
#  ('airplane', array([232, 206, 192, ...,  81, 103, 115], dtype=uint8)),
#  ('airplane', array([255, 252, 232, ..., 247, 251, 255], dtype=uint8)),
#  ('airplane', array([17,  8,  4, ..., 58, 69, 43], dtype=uint8)),
#  ('airplane', array([232, 232, 232, ..., 250, 250, 250], dtype=uint8)),
#  ('airplane', array([255, 245, 255, ..., 195, 169, 152], dtype=uint8)),
#  ('airplane', array([221, 217, 212, ..., 156, 155, 151], dtype=uint8)),
#  ('airplane', array([ 80,  89, 169, ...,  36,  40, 123], dtype=uint8)),
#  ('airplane', array([252, 255, 244, ..., 248, 255, 255], dtype=uint8)),
#  ('airplane', array([202, 199, 215, ..., 172, 181, 191], dtype=uint8)),
#  ('airplane', array([242, 161,   0, ..., 249, 247,   0], dtype=uint8)),
#  ('airplane', array([197, 164, 155, ...,  80, 100,  95], dtype=uint8)),
#  ('airplane', array([192, 151, 118, ..., 130, 135, 136], dtype=uint8)),
#  ('airplane', array([255, 245, 193, ...,  55,  56,  52], dtype=uint8)),
#  ('airplane', array([170, 169, 185, ..., 154, 165, 169], dtype=uint8)),
#  ('airplane', array([223, 221, 186, ..., 216, 207, 194], dtype=uint8)),
#  ('airplane', array([213, 170, 131, ..., 240, 237, 206], dtype=uint8)),
#  ('airplane', array([225, 204, 196, ..., 200, 191, 177], dtype=uint8)),
#  ('airplane', array([203, 194, 197, ..., 186, 177, 180], dtype=uint8)),
#  ('airplane', array([255, 254, 255, ..., 234, 234, 234], dtype=uint8)),
#  ('airplane', array([185, 172, 174, ..., 152, 151, 141], dtype=uint8)),
#  ('airplane', array([255, 237, 213, ..., 201, 196, 198], dtype=uint8)),
#  ('airplane', array([145, 110,  67, ..., 139, 100,  68], dtype=uint8)),
#  ('airplane', array([231, 218, 202, ..., 196, 155, 130], dtype=uint8)),
#  ('airplane', array([159, 223, 248, ...,  77, 106, 187], dtype=uint8)),
#  ('airplane', array([ 92, 112, 113, ..., 123, 160, 168], dtype=uint8)),
#  ('airplane', array([153, 162, 159, ...,  34,  72,  74], dtype=uint8)),
#  ('airplane', array([174, 144, 149, ..., 226, 183, 186], dtype=uint8)),
#  ('airplane', array([197, 196, 182, ..., 181, 141,  93], dtype=uint8)),
#  ('airplane', array([229, 222, 213, ...,  46,  43,  39], dtype=uint8)),
#  ('airplane', array([246, 247, 231, ..., 141, 178, 212], dtype=uint8)),
#  ('airplane', array([239, 217, 192, ...,  90, 107, 103], dtype=uint8)),
#  ('airplane', array([ 10,   5,  26, ..., 162, 146, 170], dtype=uint8)),
#  ('airplane', array([222, 189, 140, ..., 221, 201, 160], dtype=uint8)),
#  ('airplane', array([165, 161, 243, ..., 236, 255, 225], dtype=uint8)),
#  ('airplane', array([238, 253, 255, ..., 176, 189, 191], dtype=uint8)),
#  ('airplane', array([197, 148, 116, ...,  75,  54,  46], dtype=uint8)),
#  ('airplane', array([159, 145, 122, ...,  96,  72,  50], dtype=uint8)),
#  ('airplane', array([247, 228, 221, ...,  36,  59,  54], dtype=uint8)),
#  ('airplane', array([187, 123,   0, ..., 230, 224, 225], dtype=uint8)),
#  ('airplane', array([240, 237, 229, ...,  43,  63,  64], dtype=uint8)),
#  ('airplane', array([66, 69, 73, ..., 61, 68, 61], dtype=uint8)),
#  ('airplane', array([241, 155, 133, ..., 234, 167, 112], dtype=uint8)),
#  ('airplane', array([231, 223, 210, ..., 255, 255, 249], dtype=uint8)),
#  ('airplane', array([139, 116,  71, ..., 176, 146,  89], dtype=uint8)),
#  ('airplane', array([180, 178, 168, ...,  72,  93,  84], dtype=uint8)),
#  ('airplane', array([149, 164, 173, ..., 216, 209, 212], dtype=uint8)),
#  ('airplane', array([241, 225, 196, ..., 165, 197, 240], dtype=uint8)),
#  ('airplane', array([41, 13,  0, ..., 18, 11,  0], dtype=uint8)),
#  ('airplane', array([183, 146, 126, ..., 215, 156, 140], dtype=uint8)),
#  ('airplane', array([247, 241, 242, ..., 178, 180, 180], dtype=uint8)),
#  ('airplane', array([159, 153, 142, ..., 116, 124, 131], dtype=uint8)),
#  ('airplane', array([160, 112, 108, ..., 210, 207, 202], dtype=uint8)),
#  ('airplane', array([149, 145, 144, ...,  11,  64,  50], dtype=uint8)),
#  ('airplane', array([250, 251, 255, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([163, 148, 109, ..., 143, 136, 111], dtype=uint8)),
#  ('airplane', array([167, 184, 173, ..., 133, 148, 134], dtype=uint8)),
#  ('airplane', array([152,  96,  79, ..., 167, 122, 101], dtype=uint8)),
#  ('airplane', array([243, 242, 244, ..., 166, 191, 207], dtype=uint8)),
#  ('airplane', array([221, 179, 136, ..., 223, 217, 206], dtype=uint8)),
#  ('airplane', array([237, 231, 232, ...,  96,  94,  94], dtype=uint8)),
#  ('airplane', array([255, 254, 255, ..., 240, 250, 250], dtype=uint8)),
#  ('airplane', array([246, 221, 177, ..., 253, 230, 182], dtype=uint8)),
#  ('airplane', array([176, 165, 167, ..., 161, 160, 150], dtype=uint8)),
#  ('airplane', array([255, 255, 248, ..., 255, 249, 250], dtype=uint8)),
#  ('airplane', array([131,  81,  63, ..., 131,  88,  61], dtype=uint8)),
#  ('airplane', array([169, 180, 212, ..., 255, 253, 243], dtype=uint8)),
#  ('airplane', array([207, 169,  87, ..., 122,  73,   0], dtype=uint8)),
#  ('airplane', array([210, 195, 186, ...,  45,  74, 101], dtype=uint8)),
#  ('airplane', array([208, 250, 255, ..., 189, 210, 211], dtype=uint8)),
#  ('airplane', array([194, 171, 139, ...,  91, 125, 138], dtype=uint8)),
#  ('airplane', array([ 88, 112, 130, ...,  65,  91, 121], dtype=uint8)),
#  ('airplane', array([246, 252, 251, ..., 133, 142, 145], dtype=uint8)),
#  ('airplane', array([152, 117,  74, ..., 173, 116,  37], dtype=uint8)),
#  ('airplane', array([168, 202, 192, ..., 110, 166, 155], dtype=uint8)),
#  ('airplane', array([200, 188, 178, ..., 193, 167, 131], dtype=uint8)),
#  ('airplane', array([201, 201, 201, ..., 167, 169, 200], dtype=uint8)),
#  ('airplane', array([199, 176, 168, ..., 209, 181, 181], dtype=uint8)),
#  ('airplane', array([145, 107,  72, ...,  64,  48,  11], dtype=uint8)),
#  ('airplane', array([131, 131, 131, ..., 107, 107, 107], dtype=uint8)),
#  ('airplane', array([137, 125, 121, ...,  53, 104, 136], dtype=uint8)),
#  ('airplane', array([176, 181, 180, ..., 168, 173, 172], dtype=uint8)),
#  ('airplane', array([152, 107,  64, ...,  23,  65,  70], dtype=uint8)),
#  ('airplane', array([178, 202, 222, ...,  93, 142, 156], dtype=uint8)),
#  ('airplane', array([ 86,  93, 102, ...,  89, 105, 112], dtype=uint8)),
#  ('airplane', array([117,  86,  25, ..., 184, 192, 191], dtype=uint8)),
#  ('airplane', array([ 54, 108, 168, ...,  14,   8,  33], dtype=uint8)),
#  ('airplane', array([172, 119,  99, ..., 191, 122, 102], dtype=uint8)),
#  ('airplane', array([194, 199, 224, ..., 176, 146, 145], dtype=uint8)),
#  ('airplane', array([229, 197,  98, ...,  33,  32,  11], dtype=uint8)),
#  ('airplane', array([246, 254, 255, ..., 211, 201, 161], dtype=uint8)),
#  ('airplane', array([255, 249, 242, ..., 224, 250, 255], dtype=uint8)),
#  ('airplane', array([189, 174, 148, ...,  22,  82,  94], dtype=uint8)),
#  ('airplane', array([205, 199, 194, ..., 155, 112, 103], dtype=uint8)),
#  ('airplane', array([104, 120, 103, ..., 122, 122, 106], dtype=uint8)),
#  ('airplane', array([180, 207, 217, ..., 156, 173, 192], dtype=uint8)),
#  ('airplane', array([184, 192, 185, ...,  83,  77,  82], dtype=uint8)),
#  ('airplane', array([233, 233, 219, ...,  24,  32,  45], dtype=uint8)),
#  ('airplane', array([154, 134, 123, ..., 123,  91,  80], dtype=uint8)),
#  ('airplane', array([204, 186,  95, ..., 222, 193, 126], dtype=uint8)),
#  ('airplane', array([ 96, 111, 130, ..., 114, 128, 150], dtype=uint8)),
#  ('airplane', array([130, 107,  75, ...,  60,  56,  45], dtype=uint8)),
#  ('airplane', array([248, 242, 223, ..., 217, 217, 211], dtype=uint8)),
#  ('airplane', array([199, 111,  64, ...,  68, 111, 108], dtype=uint8)),
#  ('airplane', array([209, 174, 134, ...,  87, 119, 132], dtype=uint8)),
#  ('airplane', array([105, 103, 103, ..., 105, 103, 103], dtype=uint8)),
#  ('airplane', array([219, 226, 223, ...,  39, 145, 146], dtype=uint8)),
#  ('airplane', array([231, 158, 136, ..., 240, 160, 135], dtype=uint8)),
#  ('airplane', array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)),
#  ('airplane', array([14, 11, 26, ..., 62, 48, 60], dtype=uint8)),
#  ('airplane', array([120,  86,  92, ...,  26,  92, 143], dtype=uint8)),
#  ('airplane', array([255, 250, 244, ..., 255, 254, 255], dtype=uint8)),
#  ('airplane', array([248, 241, 238, ..., 141, 197, 222], dtype=uint8)),
#  ('airplane', array([192, 176, 123, ...,  65, 141, 153], dtype=uint8)),
#  ('airplane', array([255, 253, 235, ...,  50,  35,  19], dtype=uint8)),
#  ('airplane', array([155,  93,  55, ..., 195, 154, 122], dtype=uint8)),
#  ('airplane', array([ 75,  92, 119, ...,  86, 119, 158], dtype=uint8)),
#  ('airplane', array([113, 146, 149, ..., 104, 110, 123], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ...,  77, 191, 151], dtype=uint8)),
#  ('airplane', array([249, 249, 249, ..., 218, 218, 218], dtype=uint8)),
#  ('airplane', array([250, 255, 252, ..., 241, 255, 255], dtype=uint8)),
#  ('airplane', array([ 47,  99,  82, ...,  69, 114, 105], dtype=uint8)),
#  ('airplane', array([146, 148, 136, ...,   9,  56,  47], dtype=uint8)),
#  ('airplane', array([252, 252, 252, ..., 130, 142, 148], dtype=uint8)),
#  ('airplane', array([114, 110, 105, ..., 146, 152, 151], dtype=uint8)),
#  ('airplane', array([253, 255, 255, ..., 254, 254, 254], dtype=uint8)),
#  ('airplane', array([154, 129, 127, ..., 218, 219, 223], dtype=uint8)),
#  ('airplane', array([241, 184, 115, ...,  76,  85,  99], dtype=uint8)),
#  ('airplane', array([182, 148, 165, ..., 119, 109,  99], dtype=uint8)),
#  ('airplane', array([137, 155, 216, ..., 180, 175, 207], dtype=uint8)),
#  ('airplane', array([231, 173, 137, ..., 163, 187, 199], dtype=uint8)),
#  ('airplane', array([199, 179, 174, ..., 165, 157, 150], dtype=uint8)),
#  ('airplane', array([204, 159, 126, ..., 214, 168, 127], dtype=uint8)),
#  ('airplane', array([247, 217, 190, ..., 204, 167, 145], dtype=uint8)),
#  ('airplane', array([204, 149, 136, ..., 216, 161, 116], dtype=uint8)),
#  ('airplane', array([217, 214, 206, ...,  97,  73,  27], dtype=uint8)),
#  ('airplane', array([193, 199, 206, ...,  28,  50,  38], dtype=uint8)),
#  ('airplane', array([128, 214, 250, ..., 157, 227, 255], dtype=uint8)),
#  ('airplane', array([138, 145, 112, ..., 140, 136, 111], dtype=uint8)),
#  ('airplane', array([195, 147, 119, ..., 163,  68,  58], dtype=uint8)),
#  ('airplane', array([213, 173, 145, ...,  15,  10,  19], dtype=uint8)),
#  ('airplane', array([253, 253, 253, ..., 134, 134, 134], dtype=uint8)),
#  ('airplane', array([140, 120, 115, ..., 178, 130, 106], dtype=uint8)),
#  ('airplane', array([199, 161,  65, ..., 173, 138,  65], dtype=uint8)),
#  ('airplane', array([225, 206, 199, ..., 138, 128,  81], dtype=uint8)),
#  ('airplane', array([186, 165, 113, ..., 170, 159,  91], dtype=uint8)),
#  ('airplane', array([164, 155, 146, ..., 152, 158, 187], dtype=uint8)),
#  ('airplane', array([106,  63,  44, ..., 131,  76,   1], dtype=uint8)),
#  ('airplane', array([207, 211, 205, ..., 186, 177, 168], dtype=uint8)),
#  ('airplane', array([194, 127, 112, ...,  94,  71,  86], dtype=uint8)),
#  ('airplane', array([215, 186, 125, ..., 167, 140,  89], dtype=uint8)),
#  ('airplane', array([187, 135, 123, ..., 227, 188, 156], dtype=uint8)),
#  ('airplane', array([227, 214, 188, ..., 228, 216, 192], dtype=uint8)),
#  ('airplane', array([117,  65,  29, ..., 127,  72,  35], dtype=uint8)),
#  ('airplane', array([178, 185, 182, ..., 145, 181, 211], dtype=uint8)),
#  ('airplane', array([238, 217, 132, ..., 111, 115, 109], dtype=uint8)),
#  ('airplane', array([255, 250, 251, ..., 255, 253, 255], dtype=uint8)),
#  ('airplane', array([146, 158, 170, ..., 142, 126, 119], dtype=uint8)),
#  ('airplane', array([96, 86, 92, ..., 29, 54, 88], dtype=uint8)),
#  ('airplane', array([250, 254, 255, ..., 253, 255, 255], dtype=uint8)),
#  ('airplane', array([177, 149, 114, ..., 187, 154, 115], dtype=uint8)),
#  ('airplane', array([233, 233, 233, ..., 182, 182, 182], dtype=uint8)),
#  ('airplane', array([198, 153, 149, ..., 168, 109, 100], dtype=uint8)),
#  ('airplane', array([255, 255, 254, ...,  78,  88,  98], dtype=uint8)),
#  ('airplane', array([101,  74,   0, ..., 129,  73,   0], dtype=uint8)),
#  ('airplane', array([232, 223, 213, ...,  79,  92,  90], dtype=uint8)),
#  ('airplane', array([215, 163, 127, ...,  99,  59,  40], dtype=uint8)),
#  ('airplane', array([159, 165, 200, ..., 131, 154, 200], dtype=uint8)),
#  ('airplane', array([ 23, 145, 109, ...,  39,  79,  68], dtype=uint8)),
#  ('airplane', array([189, 189, 189, ..., 184, 184, 184], dtype=uint8)),
#  ('airplane', array([163, 145, 104, ...,  38,  33,   2], dtype=uint8)),
#  ('airplane', array([185, 171, 149, ..., 177, 169, 152], dtype=uint8)),
#  ('airplane', array([189, 180, 176, ..., 135, 101,  65], dtype=uint8)),
#  ('airplane', array([215, 185, 168, ..., 224, 198, 186], dtype=uint8)),
#  ('airplane', array([207, 194, 196, ..., 217, 223, 222], dtype=uint8)),
#  ('airplane', array([215, 210, 201, ..., 117, 101, 102], dtype=uint8)),
#  ('airplane', array([182, 172, 148, ..., 153, 164, 172], dtype=uint8)),
#  ('airplane', array([183, 189, 170, ..., 176, 178, 178], dtype=uint8)),
#  ('airplane', array([236, 228, 229, ...,  55,  68,  66], dtype=uint8)),
#  ('airplane', array([232, 201, 186, ..., 202, 204, 205], dtype=uint8)),
#  ('airplane', array([155, 157, 157, ..., 122,  89,  74], dtype=uint8)),
#  ('airplane', array([200, 148, 101, ..., 141, 117,  89], dtype=uint8)),
#  ('airplane', array([237,  96,   0, ..., 182, 171, 191], dtype=uint8)),
#  ('airplane', array([216, 216, 216, ..., 202, 211, 185], dtype=uint8)),
#  ('airplane', array([ 82,  98,  64, ...,  79, 150, 133], dtype=uint8)),
#  ('airplane', array([254, 250, 222, ..., 255, 243, 221], dtype=uint8)),
#  ('airplane', array([242, 225, 158, ..., 250, 237, 185], dtype=uint8)),
#  ('airplane', array([ 81,  82,  62, ...,  72, 148, 154], dtype=uint8)),
#  ('airplane', array([219, 220, 218, ..., 212, 213, 209], dtype=uint8)),
#  ('airplane', array([254, 254, 254, ..., 170, 191, 206], dtype=uint8)),
#  ('airplane', array([175, 129, 111, ..., 199, 158, 143], dtype=uint8)),
#  ('airplane', array([248, 244, 243, ...,  98, 105, 144], dtype=uint8)),
#  ('airplane', array([149, 111,  15, ..., 148, 139,  96], dtype=uint8)),
#  ('airplane', array([135,  99,  89, ..., 229, 211, 188], dtype=uint8)),
#  ('airplane', array([215, 158, 113, ..., 217, 163, 116], dtype=uint8)),
#  ('airplane', array([ 67,  97, 108, ...,  27,  54,  64], dtype=uint8)),
#  ('airplane', array([137,  81,  40, ..., 161,  94,  49], dtype=uint8)),
#  ('airplane', array([227, 182,  95, ..., 109, 101,  34], dtype=uint8)),
#  ('airplane', array([255, 255, 251, ..., 255, 251, 255], dtype=uint8)),
#  ('airplane', array([170, 139, 114, ..., 174, 138, 114], dtype=uint8)),
#  ('airplane', array([239, 222, 225, ..., 176, 152, 140], dtype=uint8)),
#  ('airplane', array([225, 232, 225, ..., 154, 152, 134], dtype=uint8)),
#  ('airplane', array([243, 168, 124, ..., 240, 168, 120], dtype=uint8)),
#  ('airplane', array([251, 249, 248, ...,  88, 101,  99], dtype=uint8)),
#  ('airplane', array([  9,   9,   9, ..., 212, 212, 212], dtype=uint8)),
#  ('airplane', array([164, 124, 105, ..., 151, 122, 107], dtype=uint8)),
#  ('airplane', array([161, 156, 147, ..., 170, 161, 148], dtype=uint8)),
#  ('airplane', array([182, 164,  99, ...,  56,  42,  30], dtype=uint8)),
#  ('airplane', array([255, 185, 151, ...,  95,  78,  29], dtype=uint8)),
#  ('airplane', array([227, 240, 248, ..., 234, 244, 254], dtype=uint8)),
#  ('airplane', array([251, 255, 255, ..., 255, 249, 255], dtype=uint8)),
#  ('airplane', array([182, 182, 182, ..., 181, 181, 181], dtype=uint8)),
#  ('airplane', array([242, 242, 242, ..., 114, 114, 114], dtype=uint8)),
#  ('airplane', array([150, 150, 150, ..., 168, 168, 168], dtype=uint8)),
#  ('airplane', array([157, 167, 184, ..., 215, 216, 226], dtype=uint8)),
#  ('airplane', array([123,  95,  78, ...,  59,  79,  90], dtype=uint8)),
#  ('airplane', array([62, 95, 51, ..., 45, 76, 31], dtype=uint8)),
#  ('airplane', array([180, 133, 119, ...,  93,  95, 105], dtype=uint8)),
#  ('airplane', array([180, 185, 124, ...,  80,  92,  72], dtype=uint8)),
#  ('airplane', array([236, 204, 175, ..., 178, 193, 196], dtype=uint8)),
#  ('airplane', array([163, 158, 159, ..., 151, 141, 141], dtype=uint8)),
#  ('airplane', array([65, 31, 42, ..., 16, 11, 12], dtype=uint8)),
#  ('airplane', array([168, 172, 167, ..., 124, 134, 134], dtype=uint8)),
#  ('airplane', array([101,  74,  30, ...,  94,  66,  35], dtype=uint8)),
#  ('airplane', array([192,  98,  55, ..., 186, 114,  66], dtype=uint8)),
#  ('airplane', array([205, 164, 115, ..., 207, 170, 112], dtype=uint8)),
#  ('airplane', array([190, 178, 166, ..., 164, 193, 220], dtype=uint8)),
#  ('airplane', array([122, 110, 108, ..., 132, 120, 116], dtype=uint8)),
#  ('airplane', array([227, 227, 227, ..., 218, 218, 218], dtype=uint8)),
#  ('airplane', array([228, 201, 137, ..., 113, 107,  88], dtype=uint8)),
#  ('airplane', array([157, 106,  44, ..., 157, 102,  51], dtype=uint8)),
#  ('airplane', array([224, 221, 223, ...,  85,  82,  84], dtype=uint8)),
#  ('airplane', array([166, 144, 119, ..., 137, 129, 112], dtype=uint8)),
#  ('airplane', array([168,  99,  66, ...,  84,  54,  43], dtype=uint8)),
#  ('airplane', array([185, 184, 188, ...,  18,  66, 108], dtype=uint8)),
#  ('airplane', array([173, 172, 174, ..., 126, 163, 185], dtype=uint8)),
#  ('airplane', array([210, 141,  62, ...,   0,   2,   1], dtype=uint8)),
# ...
#  ('airplane', array([163, 166, 171, ...,  57,  73,  79], dtype=uint8)),
#  ('airplane', array([ 92,  63,  24, ..., 199, 158, 119], dtype=uint8)),
#  ('airplane', array([ 18,  39,  47, ..., 122, 128, 133], dtype=uint8)),
#  ('airplane', array([215, 194, 172, ..., 196, 169, 155], dtype=uint8)),
#  ('airplane', array([254, 255, 253, ..., 250, 251, 247], dtype=uint8)),
#  ('airplane', array([200, 128,  81, ...,  76,  80,  85], dtype=uint8)),
#  ('airplane', array([255, 145, 102, ..., 193, 104,  83], dtype=uint8)),
#  ('airplane', array([112,  83,  56, ..., 174, 202, 213], dtype=uint8)),
#  ('airplane', array([ 32,  32,  32, ..., 155, 155, 155], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 255, 255, 255], dtype=uint8)),
#  ('airplane', array([251, 246, 247, ..., 204, 183, 156], dtype=uint8)),
#  ('airplane', array([184, 184, 168, ..., 239, 230, 203], dtype=uint8)),
#  ('airplane', array([240, 243, 228, ...,  71,  82,  79], dtype=uint8)),
#  ('airplane', array([223, 214, 205, ...,  92,  89,  84], dtype=uint8)),
#  ('airplane', array([163, 162, 142, ..., 116, 114, 120], dtype=uint8)),
#  ('airplane', array([ 68, 110,  99, ...,  70, 123, 110], dtype=uint8)),
#  ('airplane', array([119,  92,  55, ..., 202, 161, 138], dtype=uint8)),
#  ('airplane', array([133, 104,  90, ..., 130, 104,  98], dtype=uint8)),
#  ('airplane', array([ 87,  88, 108, ...,  69,  79, 109], dtype=uint8)),
#  ('airplane', array([114, 104,  97, ...,  52,  49,  41], dtype=uint8)),
#  ('airplane', array([255, 254, 234, ...,   0, 128,  88], dtype=uint8)),
#  ('airplane', array([152, 225, 245, ...,   2,   0,   8], dtype=uint8)),
#  ('airplane', array([ 69, 110, 103, ..., 137, 144, 164], dtype=uint8)),
#  ('airplane', array([138,  72,  47, ..., 175, 128, 107], dtype=uint8)),
#  ('airplane', array([124,  82,  69, ..., 172, 151, 136], dtype=uint8)),
#  ('airplane', array([250, 250, 250, ..., 137, 137, 137], dtype=uint8)),
#  ('airplane', array([108, 105,  97, ...,  90,  94,  88], dtype=uint8)),
#  ('airplane', array([203, 172, 169, ..., 107, 117, 127], dtype=uint8)),
#  ('airplane', array([191, 182, 178, ..., 191, 172, 157], dtype=uint8)),
#  ('airplane', array([  0,   0,  61, ...,  51,  92, 165], dtype=uint8)),
#  ('airplane', array([196, 160, 106, ..., 236, 240, 251], dtype=uint8)),
#  ('airplane', array([226, 156, 139, ..., 233, 147, 135], dtype=uint8)),
#  ('airplane', array([248, 171,  45, ..., 245, 251, 240], dtype=uint8)),
#  ('airplane', array([252, 240, 234, ..., 247, 232, 229], dtype=uint8)),
#  ('airplane', array([172,  98,  10, ..., 156, 128, 104], dtype=uint8)),
#  ('airplane', array([ 62, 108, 116, ...,   8,  24,  13], dtype=uint8)),
#  ('airplane', array([175, 126,  70, ...,  60,  66,  47], dtype=uint8)),
#  ('airplane', array([203, 179, 157, ..., 126, 123, 132], dtype=uint8)),
#  ('airplane', array([248, 239, 225, ..., 239, 236, 228], dtype=uint8)),
#  ('airplane', array([255, 255, 236, ..., 237, 231, 218], dtype=uint8)),
#  ('airplane', array([199, 203, 174, ..., 169, 122,  90], dtype=uint8)),
#  ('airplane', array([189, 131, 149, ..., 140,  87,  77], dtype=uint8)),
#  ('airplane', array([140,  73,  58, ...,  30,  15,  13], dtype=uint8)),
#  ('airplane', array([41, 36, 27, ..., 20, 56, 64], dtype=uint8)),
#  ('airplane', array([255, 197, 118, ...,  51,  39,  39], dtype=uint8)),
#  ('airplane', array([212, 217, 216, ..., 211, 198, 182], dtype=uint8)),
#  ('airplane', array([143, 142,  84, ...,  25,  35,  29], dtype=uint8)),
#  ('airplane', array([190, 165, 163, ..., 115,  73,  60], dtype=uint8)),
#  ('airplane', array([169, 136,  90, ..., 175, 147, 117], dtype=uint8)),
#  ('airplane', array([235, 236, 232, ..., 244, 245, 243], dtype=uint8)),
#  ('airplane', array([193, 145,  87, ..., 211, 173, 125], dtype=uint8)),
#  ('airplane', array([213, 182, 161, ...,  26,  81,  64], dtype=uint8)),
#  ('airplane', array([133, 107,  47, ..., 253, 251, 243], dtype=uint8)),
#  ('airplane', array([255, 243, 194, ..., 255, 230, 211], dtype=uint8)),
#  ('airplane', array([133, 197, 228, ..., 131, 155, 179], dtype=uint8)),
#  ('airplane', array([82, 78, 54, ..., 80, 76, 52], dtype=uint8)),
#  ('airplane', array([129, 131, 119, ...,  79,  93,  91], dtype=uint8)),
#  ('airplane', array([184, 122,  81, ...,  87,  66,  45], dtype=uint8)),
#  ('airplane', array([162, 165, 163, ..., 120, 177, 192], dtype=uint8)),
#  ('airplane', array([226, 222, 217, ...,  75,  81,  88], dtype=uint8)),
#  ('airplane', array([182, 115,  88, ..., 179, 116,  56], dtype=uint8)),
#  ('airplane', array([156, 161, 176, ...,  92, 111, 124], dtype=uint8)),
#  ('airplane', array([212, 175, 141, ...,  42,  89,  86], dtype=uint8)),
#  ('airplane', array([195, 105,  70, ...,  69,  75,  82], dtype=uint8)),
#  ('airplane', array([161, 100,  66, ...,  67,  91,  83], dtype=uint8)),
#  ('airplane', array([ 23,  17,  36, ..., 251, 255, 252], dtype=uint8)),
#  ('airplane', array([142,  76,  57, ..., 200, 168, 162], dtype=uint8)),
#  ('airplane', array([223, 179, 148, ..., 244, 210, 181], dtype=uint8)),
#  ('airplane', array([246, 200, 116, ...,  64,  82,  81], dtype=uint8)),
#  ('airplane', array([181, 166, 180, ..., 146, 172, 196], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 137, 137, 137], dtype=uint8)),
#  ('airplane', array([255, 239, 235, ..., 252, 254, 254], dtype=uint8)),
#  ('airplane', array([193, 110,  78, ..., 179, 107,  97], dtype=uint8)),
#  ('airplane', array([255, 249, 255, ..., 133, 120, 118], dtype=uint8)),
#  ('airplane', array([120, 143, 175, ..., 102, 122, 169], dtype=uint8)),
#  ('airplane', array([140,  96,  59, ...,  75,  53,  25], dtype=uint8)),
#  ('airplane', array([213, 115,  69, ..., 198, 156, 239], dtype=uint8)),
#  ('airplane', array([239, 239, 225, ..., 216, 240, 252], dtype=uint8)),
#  ('airplane', array([204, 200, 205, ..., 200, 177, 169], dtype=uint8)),
#  ('airplane', array([191, 133,  84, ...,  32,  41,  74], dtype=uint8)),
#  ('airplane', array([246, 247, 243, ..., 253, 255, 255], dtype=uint8)),
#  ('airplane', array([194, 183, 179, ..., 177, 163, 144], dtype=uint8)),
#  ('airplane', array([247, 222, 212, ...,  36,  39,  43], dtype=uint8)),
#  ('airplane', array([0, 0, 4, ..., 0, 0, 9], dtype=uint8)),
#  ('airplane', array([157, 146, 148, ...,  84,  85,  75], dtype=uint8)),
#  ('airplane', array([174, 156, 149, ..., 113, 106,  87], dtype=uint8)),
#  ('airplane', array([163, 130,  81, ..., 195, 194, 190], dtype=uint8)),
#  ('airplane', array([185, 185, 185, ...,  43,  43,  43], dtype=uint8)),
#  ('airplane', array([181, 120,  76, ..., 209, 176, 160], dtype=uint8)),
#  ('airplane', array([246, 218, 194, ..., 250, 219, 194], dtype=uint8)),
#  ('airplane', array([250, 245, 246, ..., 166, 164, 164], dtype=uint8)),
#  ('airplane', array([196, 163, 148, ..., 150, 134, 122], dtype=uint8)),
#  ('airplane', array([91, 79, 67, ..., 31, 67, 67], dtype=uint8)),
#  ('airplane', array([  6,   3,   0, ..., 126, 134, 147], dtype=uint8)),
#  ('airplane', array([228, 233, 236, ...,  66,  83,  96], dtype=uint8)),
#  ('airplane', array([252, 254, 255, ..., 255, 246, 255], dtype=uint8)),
#  ('airplane', array([188, 185, 181, ..., 184, 184, 184], dtype=uint8)),
#  ('airplane', array([223, 193, 164, ...,  71,  52,  67], dtype=uint8)),
#  ('airplane', array([195, 169, 145, ..., 194, 177, 156], dtype=uint8)),
#  ('airplane', array([255, 245, 245, ..., 160, 179, 186], dtype=uint8)),
#  ('airplane', array([230, 209, 194, ..., 190, 203, 219], dtype=uint8)),
#  ('airplane', array([246, 217, 190, ..., 252, 229, 221], dtype=uint8)),
#  ('airplane', array([215, 225, 195, ..., 248, 236, 212], dtype=uint8)),
#  ('airplane', array([254, 254, 254, ..., 252, 251, 255], dtype=uint8)),
#  ('airplane', array([187, 155, 102, ..., 128,  99,  14], dtype=uint8)),
#  ('airplane', array([252, 252, 252, ..., 235, 235, 235], dtype=uint8)),
#  ('airplane', array([240, 235, 226, ..., 241, 225, 213], dtype=uint8)),
#  ('airplane', array([226, 189, 163, ...,  91,  77,  54], dtype=uint8)),
#  ('airplane', array([244, 244, 244, ..., 195, 188, 179], dtype=uint8)),
#  ('airplane', array([228, 228, 228, ..., 219, 219, 207], dtype=uint8)),
#  ('airplane', array([148, 141, 114, ...,  86,  96,  96], dtype=uint8)),
#  ('airplane', array([205, 168, 110, ..., 169, 106,   0], dtype=uint8)),
#  ('airplane', array([254, 255, 247, ..., 151, 167, 184], dtype=uint8)),
#  ('airplane', array([240, 237, 239, ..., 172, 196, 186], dtype=uint8)),
#  ('airplane', array([191, 199, 212, ..., 141, 159, 182], dtype=uint8)),
#  ('airplane', array([215, 193, 157, ...,  79, 112, 108], dtype=uint8)),
#  ('airplane', array([208, 165, 102, ..., 118, 136, 165], dtype=uint8)),
#  ('airplane', array([248, 206, 177, ..., 243, 201, 166], dtype=uint8)),
#  ('airplane', array([255, 250, 250, ..., 163, 183, 160], dtype=uint8)),
#  ('airplane', array([220, 162, 126, ..., 221, 180, 157], dtype=uint8)),
#  ('airplane', array([125, 104,  89, ...,  48,  69,  60], dtype=uint8)),
#  ('airplane', array([255, 255, 255, ..., 255, 255, 254], dtype=uint8)),
#  ('airplane', array([124,  59,  31, ...,  46,  44,  44], dtype=uint8)),
#  ('airplane', array([149, 139, 121, ..., 154, 169, 171], dtype=uint8)),
#  ('airplane', array([255, 254, 255, ..., 255, 251, 255], dtype=uint8)),
#  ('airplane', array([180, 166, 118, ..., 148, 142,  97], dtype=uint8)),
#  ('airplane', array([253, 186, 161, ..., 243, 193, 163], dtype=uint8)),
#  ('airplane', array([172, 172, 186, ...,  30,  76,  64], dtype=uint8)),
#  ('airplane', array([146, 169, 171, ..., 121, 168, 159], dtype=uint8)),
#  ('airplane', array([155, 126, 111, ..., 233, 237, 242], dtype=uint8)),
#  ('airplane', array([164, 157, 148, ...,  84,  89,  87], dtype=uint8)),
#  ('airplane', array([235, 216, 209, ..., 147, 122, 120], dtype=uint8)),
#  ('airplane', array([223, 171, 134, ..., 131, 112, 107], dtype=uint8)),
#  ('airplane', array([234, 184, 154, ..., 207, 216, 220], dtype=uint8)),
#  ('airplane', array([3, 0, 4, ..., 0, 0, 4], dtype=uint8)),
#  ('airplane', array([220, 124,  78, ..., 192, 113,  50], dtype=uint8)),
#  ('airplane', array([182, 171, 173, ..., 175, 164, 126], dtype=uint8)),
#  ('airplane', array([ 91, 114, 106, ...,  91, 109, 126], dtype=uint8)),
#  ('airplane', array([115,  79,  39, ..., 196, 169, 132], dtype=uint8)),
#  ('airplane', array([221, 183, 148, ..., 213, 175, 151], dtype=uint8)),
#  ('airplane', array([186, 186, 186, ..., 199, 199, 199], dtype=uint8)),
#  ('airplane', array([254, 241, 227, ...,  37,  62,  82], dtype=uint8)),
#  ('airplane', array([180, 148,  83, ..., 195, 165, 106], dtype=uint8)),
#  ('airplane', array([255, 252, 255, ..., 223, 231, 254], dtype=uint8)),
#  ('airplane', array([130, 113, 104, ..., 191, 191, 207], dtype=uint8)),
#  ('airplane', array([192, 135, 110, ..., 204, 139, 118], dtype=uint8)),
#  ('airplane', array([ 75, 112, 104, ...,  92, 113,  80], dtype=uint8)),
#  ('airplane', array([161, 143, 102, ...,  52, 126, 150], dtype=uint8)),
#  ('airplane', array([231, 241, 235, ...,  55, 109, 116], dtype=uint8)),
#  ('airplane', array([249, 208, 176, ..., 228, 194, 165], dtype=uint8)),
#  ('airplane', array([222, 199, 177, ..., 208, 192, 176], dtype=uint8)),
#  ('airplane', array([232, 218, 230, ..., 227, 216, 232], dtype=uint8)),
#  ('airplane', array([64, 57, 60, ..., 72, 63, 66], dtype=uint8)),
#  ('airplane', array([ 36,  28,  38, ...,  47,  78, 111], dtype=uint8)),
#  ('airplane', array([171, 144, 118, ..., 163, 174, 204], dtype=uint8)),
#  ('airplane', array([251, 250, 254, ..., 179, 155, 143], dtype=uint8)),
#  ('airplane', array([189, 201, 129, ...,  82, 113, 138], dtype=uint8)),
#  ('airplane', array([158,  75,  67, ..., 156,  87,  68], dtype=uint8)),
#  ('airplane', array([253, 250, 236, ..., 247, 238, 228], dtype=uint8)),
#  ('airplane', array([230, 209, 182, ...,  25,  26,  24], dtype=uint8)),
#  ('airplane', array([220, 209, 177, ..., 194, 196, 190], dtype=uint8)),
#  ('airplane', array([223, 181, 144, ...,  97,  97, 103], dtype=uint8)),
#  ('airplane', array([255, 251, 255, ..., 252, 101, 104], dtype=uint8)),
#  ('airplane', array([210, 193, 174, ..., 122, 131, 145], dtype=uint8)),
#  ('airplane', array([174, 132, 103, ..., 146, 130, 123], dtype=uint8)),
#  ('airplane', array([ 92, 101, 110, ..., 121, 118, 120], dtype=uint8)),
#  ('airplane', array([242, 185, 154, ..., 129, 164, 168], dtype=uint8)),
#  ('airplane', array([201, 200, 180, ..., 183, 184, 175], dtype=uint8)),
#  ('airplane', array([156, 118,  84, ..., 158, 119, 110], dtype=uint8)),
#  ('airplane', array([234, 226, 226, ..., 255, 255, 252], dtype=uint8)),
#  ('airplane', array([246, 228, 175, ..., 237, 208, 123], dtype=uint8)),
#  ('airplane', array([137, 114, 106, ...,  80,  55,  65], dtype=uint8)),
#  ('airplane', array([204, 218, 230, ...,  55,  85, 104], dtype=uint8)),
#  ('airplane', array([240, 194, 163, ..., 240, 196, 165], dtype=uint8)),
#  ('airplane', array([166, 135,  96, ..., 181, 138,  11], dtype=uint8)),
#  ('airplane', array([ 62,   0,   3, ..., 191,  94,  30], dtype=uint8)),
#  ('airplane', array([250, 148, 149, ..., 103,  59,  46], dtype=uint8)),
#  ('airplane', array([174,  91,  39, ..., 196, 128,  83], dtype=uint8)),
#  ('airplane', array([117, 117, 117, ...,  73,  73,  73], dtype=uint8)),
#  ('airplane', array([179, 163, 140, ..., 202, 104,  92], dtype=uint8)),
#  ('airplane', array([248, 248, 232, ...,  68,  77,  80], dtype=uint8)),
#  ('airplane', array([244, 244, 244, ..., 243, 243, 243], dtype=uint8)),
#  ('airplane', array([239, 233, 238, ..., 123, 118, 117], dtype=uint8)),
#  ('airplane', array([164, 155, 146, ..., 129, 113, 107], dtype=uint8)),
#  ('airplane', array([142, 102,  74, ..., 160, 114,  90], dtype=uint8)),
#  ('airplane', array([164, 134,  29, ...,  67,  83,  90], dtype=uint8)),
#  ('airplane', array([255, 255, 252, ..., 186, 186, 192], dtype=uint8)),
#  ('airplane', array([209, 209, 209, ..., 115, 115, 115], dtype=uint8)),
#  ('airplane', array([204, 164, 135, ..., 204, 160, 147], dtype=uint8)),
#  ('airplane', array([228, 213, 204, ..., 199, 207, 190], dtype=uint8)),
#  ('airplane', array([228, 224, 223, ...,  30,  50,  15], dtype=uint8)),
#  ('airplane', array([51, 59, 59, ..., 45, 51, 58], dtype=uint8)),
#  ('airplane', array([228, 106,  76, ..., 246, 105,  56], dtype=uint8)),
#  ('airplane', array([ 46,  46,  46, ..., 126, 126, 126], dtype=uint8)),
#  ('airplane', array([226, 227, 225, ..., 225, 225, 225], dtype=uint8)),
#  ('airplane', array([243, 226, 207, ..., 112, 132, 143], dtype=uint8)),
#  ('airplane', array([196, 184, 126, ..., 207, 201, 154], dtype=uint8)),
#  ('airplane', array([115,   0,   0, ...,  95,  52,   3], dtype=uint8)),
#  ('airplane', array([183, 174, 165, ..., 186, 150, 104], dtype=uint8)),
#  ('airplane', array([199, 188, 168, ..., 186, 167, 152], dtype=uint8)),
#  ('airplane', array([172, 163, 143, ..., 106, 104,  93], dtype=uint8)),
#  ('airplane', array([170, 165, 104, ..., 158, 210, 157], dtype=uint8)),
#  ('airplane', array([204, 168, 132, ..., 201, 198, 177], dtype=uint8)),
#  ('airplane', array([ 0,  4,  1, ...,  0,  0, 11], dtype=uint8)),
#  ('airplane', array([166, 187, 195, ..., 180, 208, 209], dtype=uint8)),
#  ('airplane', array([236, 225, 221, ...,  69, 119, 117], dtype=uint8)),
#  ('airplane', array([183, 175, 175, ..., 119, 130, 127], dtype=uint8)),
#  ('airplane', array([139,  84,  27, ..., 122,  89,   9], dtype=uint8)),
#  ('airplane', array([149, 131, 120, ..., 101, 145, 146], dtype=uint8)),
#  ('airplane', array([203, 162, 129, ..., 157, 150, 123], dtype=uint8)),
#  ('airplane', array([146, 146, 146, ..., 149, 149, 149], dtype=uint8)),
#  ('airplane', array([232, 255, 255, ..., 249, 254, 253], dtype=uint8)),
#  ('airplane', array([170, 148, 120, ...,  52,  74,  86], dtype=uint8)),
#  ('airplane', array([158, 119,  50, ..., 185, 152,  79], dtype=uint8)),
#  ('airplane', array([219, 198, 147, ..., 221, 214, 211], dtype=uint8)),
#  ('airplane', array([63, 24, 10, ..., 10, 11,  7], dtype=uint8)),
#  ('airplane', array([199, 210, 190, ..., 132, 148, 137], dtype=uint8)),
#  ('airplane', array([135,  99,  51, ..., 184, 202, 195], dtype=uint8)),
#  ('airplane', array([250, 242, 235, ..., 158, 152,  85], dtype=uint8)),
#  ('airplane', array([208, 211, 202, ..., 236, 243, 236], dtype=uint8)),
#  ('airplane', array([176, 189, 175, ...,  80,  98,  99], dtype=uint8)),
#  ('airplane', array([168, 160, 147, ..., 124, 118,  89], dtype=uint8)),
#  ('airplane', array([196, 141, 114, ...,   0,   0,   5], dtype=uint8)),
#  ...]

# %%
testpoint=[]
testlabel=[]
for i in testdata:
    testlabel.append(i[0])
    testpoint.append(i[1])

# %%
testpoint=np.array(testpoint)
